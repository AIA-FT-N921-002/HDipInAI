# %%
import heapq
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt

from pyvis.network import Network

# %%
airport_graph_dict = {
    'Seattle': {'San Francisco':807,'Denver':1331,'Chicago':2097},
    'San Francisco': {'Seattle':807,'Denver':1267,'Los Angeles':381},
    'Los Angeles': {'San Francisco':381,'Denver':1015,'Kansas City':1663,'Dallas':1435},
    'Denver': {'Seattle':1331,'San Francisco':1267,'Los Angeles':1015,'Kansas City':599,'Chicago':1003},
    'Chicago': {'Seattle':2097,'Denver':1003,'Kansas City':533,'New York':787,'Boston':983},
    'Boston': {'Chicago':983,'New York':214},
    'New York': {'Boston':214,'Chicago':787,'Kansas City':1260,'Atlanta':888},
    'Kansas City': {'Chicago':533,'New York':1260,'Atlanta':864,'Dallas':496,'Los Angeles':1663,'Denver':599},
    'Atlanta': {'New York':888,'Miami':661,'Houston':810,'Dallas':781,'Kansas City':864},
    'Dallas': {'Atlanta':781,'Houston':239,'Los Angeles':1435,'Kansas City':496},
    'Houston': {'Dallas':239,'Atlanta':810,'Miami':1187},
    'Miami': {'Houston':1187,'Atlanta':661}
}

# %%
def calculate_distances(graph, starting_vertex):
    distances = {vertex: float('infinity') for vertex in graph}    
    distances[starting_vertex] = 0    
    pq = [(0, starting_vertex)]
    
    while len(pq) > 0:
        print('----------------')
        print('Priority Queue:\n',pq)            
        print('Distances:\n',distances)                
        
        current_distance, current_vertex = heapq.heappop(pq)        
        
        print(f'\npulling {current_vertex} (distance to {current_vertex} = {current_distance}) from priority queue...')        
        
        # Nodes can get added to the priority queue multiple times. We only
        # process a vertex the first time we remove it from the priority queue.        
        print(f'\nIs the current distance to {current_vertex} ({current_distance}) greater than {current_vertex}\'s distance ({distances[current_vertex]})?', end=" ")
        
        if current_distance > distances[current_vertex]:                        
            print('Yes. Move on.')
            continue
            
        print('No! Let\'s analyze it:')
        print(graph[current_vertex].items())

        for neighbor, weight in graph[current_vertex].items():
            print(f'\ndistance to {neighbor} = current_distance + weight = {current_distance} + {weight}')
            distance = current_distance + weight
            print(f'thus, distance to {neighbor} = {distance}')
            
            # Only consider this new path if it's better than any path we've
            # already found.
            print(f'Is this distance better than the current estimate ({distances[neighbor]})?')
            if distance < distances[neighbor]:
                print(f'Yes! A better path thru {neighbor} was found: {distance}')
                distances[neighbor] = distance
                heapq.heappush(pq, (distance, neighbor)) 
                print(f'Pushing {distance, neighbor} to priority queue...')
            else:
                print('No.')
        
    print('\n\nResult')        
    
    return distances

# %%
print(calculate_distances(airport_graph_dict, 'Seattle'))
# Out:
# ----------------
# Priority Queue:
#  [(0, 'Seattle')]
# Distances:
#  {'Seattle': 0, 'San Francisco': inf, 'Los Angeles': inf, 'Denver': inf, 'Chicago': inf, 'Boston': inf, 'New York': inf, 'Kansas City': inf, 'Atlanta': inf, 'Dallas': inf, 'Houston': inf, 'Miami': inf}
#
# pulling Seattle (distance to Seattle = 0) from priority queue...
#
# Is the current distance to Seattle (0) greater than Seattle's distance (0)? No! Let's analyze it:
# dict_items([('San Francisco', 807), ('Denver', 1331), ('Chicago', 2097)])
#
# distance to San Francisco = current_distance + weight = 0 + 807
# thus, distance to San Francisco = 807
# Is this distance better than the current estimate (inf)?
# Yes! A better path thru San Francisco was found: 807
# Pushing (807, 'San Francisco') to priority queue...
#
# distance to Denver = current_distance + weight = 0 + 1331
# thus, distance to Denver = 1331
# Is this distance better than the current estimate (inf)?
# Yes! A better path thru Denver was found: 1331
# Pushing (1331, 'Denver') to priority queue...
#
# distance to Chicago = current_distance + weight = 0 + 2097
# thus, distance to Chicago = 2097
# Is this distance better than the current estimate (inf)?
# Yes! A better path thru Chicago was found: 2097
# Pushing (2097, 'Chicago') to priority queue...
# ----------------
# Priority Queue:
#  [(807, 'San Francisco'), (1331, 'Denver'), (2097, 'Chicago')]
# Distances:
#  {'Seattle': 0, 'San Francisco': 807, 'Los Angeles': inf, 'Denver': 1331, 'Chicago': 2097, 'Boston': inf, 'New York': inf, 'Kansas City': inf, 'Atlanta': inf, 'Dallas': inf, 'Houston': inf, 'Miami': inf}
#
# pulling San Francisco (distance to San Francisco = 807) from priority queue...
#
# Is the current distance to San Francisco (807) greater than San Francisco's distance (807)? No! Let's analyze it:
# dict_items([('Seattle', 807), ('Denver', 1267), ('Los Angeles', 381)])
#
# distance to Seattle = current_distance + weight = 807 + 807
# thus, distance to Seattle = 1614
# Is this distance better than the current estimate (0)?
# No.
#
# distance to Denver = current_distance + weight = 807 + 1267
# thus, distance to Denver = 2074
# Is this distance better than the current estimate (1331)?
# No.
#
# distance to Los Angeles = current_distance + weight = 807 + 381
# thus, distance to Los Angeles = 1188
# Is this distance better than the current estimate (inf)?
# Yes! A better path thru Los Angeles was found: 1188
# Pushing (1188, 'Los Angeles') to priority queue...
# ----------------
# Priority Queue:
#  [(1188, 'Los Angeles'), (2097, 'Chicago'), (1331, 'Denver')]
# Distances:
#  {'Seattle': 0, 'San Francisco': 807, 'Los Angeles': 1188, 'Denver': 1331, 'Chicago': 2097, 'Boston': inf, 'New York': inf, 'Kansas City': inf, 'Atlanta': inf, 'Dallas': inf, 'Houston': inf, 'Miami': inf}
#
# pulling Los Angeles (distance to Los Angeles = 1188) from priority queue...
#
# Is the current distance to Los Angeles (1188) greater than Los Angeles's distance (1188)? No! Let's analyze it:
# dict_items([('San Francisco', 381), ('Denver', 1015), ('Kansas City', 1663), ('Dallas', 1435)])
#
# distance to San Francisco = current_distance + weight = 1188 + 381
# thus, distance to San Francisco = 1569
# Is this distance better than the current estimate (807)?
# No.
#
# distance to Denver = current_distance + weight = 1188 + 1015
# thus, distance to Denver = 2203
# Is this distance better than the current estimate (1331)?
# No.
#
# distance to Kansas City = current_distance + weight = 1188 + 1663
# thus, distance to Kansas City = 2851
# Is this distance better than the current estimate (inf)?
# Yes! A better path thru Kansas City was found: 2851
# Pushing (2851, 'Kansas City') to priority queue...
#
# distance to Dallas = current_distance + weight = 1188 + 1435
# thus, distance to Dallas = 2623
# Is this distance better than the current estimate (inf)?
# Yes! A better path thru Dallas was found: 2623
# Pushing (2623, 'Dallas') to priority queue...
# ----------------
# Priority Queue:
#  [(1331, 'Denver'), (2097, 'Chicago'), (2851, 'Kansas City'), (2623, 'Dallas')]
# Distances:
#  {'Seattle': 0, 'San Francisco': 807, 'Los Angeles': 1188, 'Denver': 1331, 'Chicago': 2097, 'Boston': inf, 'New York': inf, 'Kansas City': 2851, 'Atlanta': inf, 'Dallas': 2623, 'Houston': inf, 'Miami': inf}
#
# pulling Denver (distance to Denver = 1331) from priority queue...
#
# Is the current distance to Denver (1331) greater than Denver's distance (1331)? No! Let's analyze it:
# dict_items([('Seattle', 1331), ('San Francisco', 1267), ('Los Angeles', 1015), ('Kansas City', 599), ('Chicago', 1003)])
#
# distance to Seattle = current_distance + weight = 1331 + 1331
# thus, distance to Seattle = 2662
# Is this distance better than the current estimate (0)?
# No.
#
# distance to San Francisco = current_distance + weight = 1331 + 1267
# thus, distance to San Francisco = 2598
# Is this distance better than the current estimate (807)?
# No.
#
# distance to Los Angeles = current_distance + weight = 1331 + 1015
# thus, distance to Los Angeles = 2346
# Is this distance better than the current estimate (1188)?
# No.
#
# distance to Kansas City = current_distance + weight = 1331 + 599
# thus, distance to Kansas City = 1930
# Is this distance better than the current estimate (2851)?
# Yes! A better path thru Kansas City was found: 1930
# Pushing (1930, 'Kansas City') to priority queue...
#
# distance to Chicago = current_distance + weight = 1331 + 1003
# thus, distance to Chicago = 2334
# Is this distance better than the current estimate (2097)?
# No.
# ----------------
# Priority Queue:
#  [(1930, 'Kansas City'), (2097, 'Chicago'), (2851, 'Kansas City'), (2623, 'Dallas')]
# Distances:
#  {'Seattle': 0, 'San Francisco': 807, 'Los Angeles': 1188, 'Denver': 1331, 'Chicago': 2097, 'Boston': inf, 'New York': inf, 'Kansas City': 1930, 'Atlanta': inf, 'Dallas': 2623, 'Houston': inf, 'Miami': inf}
#
# pulling Kansas City (distance to Kansas City = 1930) from priority queue...
#
# Is the current distance to Kansas City (1930) greater than Kansas City's distance (1930)? No! Let's analyze it:
# dict_items([('Chicago', 533), ('New York', 1260), ('Atlanta', 864), ('Dallas', 496), ('Los Angeles', 1663), ('Denver', 599)])
#
# distance to Chicago = current_distance + weight = 1930 + 533
# thus, distance to Chicago = 2463
# Is this distance better than the current estimate (2097)?
# No.
#
# distance to New York = current_distance + weight = 1930 + 1260
# thus, distance to New York = 3190
# Is this distance better than the current estimate (inf)?
# Yes! A better path thru New York was found: 3190
# Pushing (3190, 'New York') to priority queue...
#
# distance to Atlanta = current_distance + weight = 1930 + 864
# thus, distance to Atlanta = 2794
# Is this distance better than the current estimate (inf)?
# Yes! A better path thru Atlanta was found: 2794
# Pushing (2794, 'Atlanta') to priority queue...
#
# distance to Dallas = current_distance + weight = 1930 + 496
# thus, distance to Dallas = 2426
# Is this distance better than the current estimate (2623)?
# Yes! A better path thru Dallas was found: 2426
# Pushing (2426, 'Dallas') to priority queue...
#
# distance to Los Angeles = current_distance + weight = 1930 + 1663
# thus, distance to Los Angeles = 3593
# Is this distance better than the current estimate (1188)?
# No.
#
# distance to Denver = current_distance + weight = 1930 + 599
# thus, distance to Denver = 2529
# Is this distance better than the current estimate (1331)?
# No.
# ----------------
# Priority Queue:
#  [(2097, 'Chicago'), (2623, 'Dallas'), (2426, 'Dallas'), (3190, 'New York'), (2794, 'Atlanta'), (2851, 'Kansas City')]
# Distances:
#  {'Seattle': 0, 'San Francisco': 807, 'Los Angeles': 1188, 'Denver': 1331, 'Chicago': 2097, 'Boston': inf, 'New York': 3190, 'Kansas City': 1930, 'Atlanta': 2794, 'Dallas': 2426, 'Houston': inf, 'Miami': inf}
#
# pulling Chicago (distance to Chicago = 2097) from priority queue...
#
# Is the current distance to Chicago (2097) greater than Chicago's distance (2097)? No! Let's analyze it:
# dict_items([('Seattle', 2097), ('Denver', 1003), ('Kansas City', 533), ('New York', 787), ('Boston', 983)])
#
# distance to Seattle = current_distance + weight = 2097 + 2097
# thus, distance to Seattle = 4194
# Is this distance better than the current estimate (0)?
# No.
#
# distance to Denver = current_distance + weight = 2097 + 1003
# thus, distance to Denver = 3100
# Is this distance better than the current estimate (1331)?
# No.
#
# distance to Kansas City = current_distance + weight = 2097 + 533
# thus, distance to Kansas City = 2630
# Is this distance better than the current estimate (1930)?
# No.
#
# distance to New York = current_distance + weight = 2097 + 787
# thus, distance to New York = 2884
# Is this distance better than the current estimate (3190)?
# Yes! A better path thru New York was found: 2884
# Pushing (2884, 'New York') to priority queue...
#
# distance to Boston = current_distance + weight = 2097 + 983
# thus, distance to Boston = 3080
# Is this distance better than the current estimate (inf)?
# Yes! A better path thru Boston was found: 3080
# Pushing (3080, 'Boston') to priority queue...
# ----------------
# Priority Queue:
#  [(2426, 'Dallas'), (2623, 'Dallas'), (2851, 'Kansas City'), (3190, 'New York'), (2794, 'Atlanta'), (2884, 'New York'), (3080, 'Boston')]
# Distances:
#  {'Seattle': 0, 'San Francisco': 807, 'Los Angeles': 1188, 'Denver': 1331, 'Chicago': 2097, 'Boston': 3080, 'New York': 2884, 'Kansas City': 1930, 'Atlanta': 2794, 'Dallas': 2426, 'Houston': inf, 'Miami': inf}
#
# pulling Dallas (distance to Dallas = 2426) from priority queue...
#
# Is the current distance to Dallas (2426) greater than Dallas's distance (2426)? No! Let's analyze it:
# dict_items([('Atlanta', 781), ('Houston', 239), ('Los Angeles', 1435), ('Kansas City', 496)])
#
# distance to Atlanta = current_distance + weight = 2426 + 781
# thus, distance to Atlanta = 3207
# Is this distance better than the current estimate (2794)?
# No.
#
# distance to Houston = current_distance + weight = 2426 + 239
# thus, distance to Houston = 2665
# Is this distance better than the current estimate (inf)?
# Yes! A better path thru Houston was found: 2665
# Pushing (2665, 'Houston') to priority queue...
#
# distance to Los Angeles = current_distance + weight = 2426 + 1435
# thus, distance to Los Angeles = 3861
# Is this distance better than the current estimate (1188)?
# No.
#
# distance to Kansas City = current_distance + weight = 2426 + 496
# thus, distance to Kansas City = 2922
# Is this distance better than the current estimate (1930)?
# No.
# ----------------
# Priority Queue:
#  [(2623, 'Dallas'), (2794, 'Atlanta'), (2665, 'Houston'), (3190, 'New York'), (3080, 'Boston'), (2884, 'New York'), (2851, 'Kansas City')]
# Distances:
#  {'Seattle': 0, 'San Francisco': 807, 'Los Angeles': 1188, 'Denver': 1331, 'Chicago': 2097, 'Boston': 3080, 'New York': 2884, 'Kansas City': 1930, 'Atlanta': 2794, 'Dallas': 2426, 'Houston': 2665, 'Miami': inf}
#
# pulling Dallas (distance to Dallas = 2623) from priority queue...
#
# Is the current distance to Dallas (2623) greater than Dallas's distance (2426)? Yes. Move on.
# ----------------
# Priority Queue:
#  [(2665, 'Houston'), (2794, 'Atlanta'), (2851, 'Kansas City'), (3190, 'New York'), (3080, 'Boston'), (2884, 'New York')]
# Distances:
#  {'Seattle': 0, 'San Francisco': 807, 'Los Angeles': 1188, 'Denver': 1331, 'Chicago': 2097, 'Boston': 3080, 'New York': 2884, 'Kansas City': 1930, 'Atlanta': 2794, 'Dallas': 2426, 'Houston': 2665, 'Miami': inf}
#
# pulling Houston (distance to Houston = 2665) from priority queue...
#
# Is the current distance to Houston (2665) greater than Houston's distance (2665)? No! Let's analyze it:
# dict_items([('Dallas', 239), ('Atlanta', 810), ('Miami', 1187)])
#
# distance to Dallas = current_distance + weight = 2665 + 239
# thus, distance to Dallas = 2904
# Is this distance better than the current estimate (2426)?
# No.
#
# distance to Atlanta = current_distance + weight = 2665 + 810
# thus, distance to Atlanta = 3475
# Is this distance better than the current estimate (2794)?
# No.
#
# distance to Miami = current_distance + weight = 2665 + 1187
# thus, distance to Miami = 3852
# Is this distance better than the current estimate (inf)?
# Yes! A better path thru Miami was found: 3852
# Pushing (3852, 'Miami') to priority queue...
# ----------------
# Priority Queue:
#  [(2794, 'Atlanta'), (2884, 'New York'), (2851, 'Kansas City'), (3190, 'New York'), (3080, 'Boston'), (3852, 'Miami')]
# Distances:
#  {'Seattle': 0, 'San Francisco': 807, 'Los Angeles': 1188, 'Denver': 1331, 'Chicago': 2097, 'Boston': 3080, 'New York': 2884, 'Kansas City': 1930, 'Atlanta': 2794, 'Dallas': 2426, 'Houston': 2665, 'Miami': 3852}
#
# pulling Atlanta (distance to Atlanta = 2794) from priority queue...
#
# Is the current distance to Atlanta (2794) greater than Atlanta's distance (2794)? No! Let's analyze it:
# dict_items([('New York', 888), ('Miami', 661), ('Houston', 810), ('Dallas', 781), ('Kansas City', 864)])
#
# distance to New York = current_distance + weight = 2794 + 888
# thus, distance to New York = 3682
# Is this distance better than the current estimate (2884)?
# No.
#
# distance to Miami = current_distance + weight = 2794 + 661
# thus, distance to Miami = 3455
# Is this distance better than the current estimate (3852)?
# Yes! A better path thru Miami was found: 3455
# Pushing (3455, 'Miami') to priority queue...
#
# distance to Houston = current_distance + weight = 2794 + 810
# thus, distance to Houston = 3604
# Is this distance better than the current estimate (2665)?
# No.
#
# distance to Dallas = current_distance + weight = 2794 + 781
# thus, distance to Dallas = 3575
# Is this distance better than the current estimate (2426)?
# No.
#
# distance to Kansas City = current_distance + weight = 2794 + 864
# thus, distance to Kansas City = 3658
# Is this distance better than the current estimate (1930)?
# No.
# ----------------
# Priority Queue:
#  [(2851, 'Kansas City'), (2884, 'New York'), (3455, 'Miami'), (3190, 'New York'), (3080, 'Boston'), (3852, 'Miami')]
# Distances:
#  {'Seattle': 0, 'San Francisco': 807, 'Los Angeles': 1188, 'Denver': 1331, 'Chicago': 2097, 'Boston': 3080, 'New York': 2884, 'Kansas City': 1930, 'Atlanta': 2794, 'Dallas': 2426, 'Houston': 2665, 'Miami': 3455}
#
# pulling Kansas City (distance to Kansas City = 2851) from priority queue...
#
# Is the current distance to Kansas City (2851) greater than Kansas City's distance (1930)? Yes. Move on.
# ----------------
# Priority Queue:
#  [(2884, 'New York'), (3080, 'Boston'), (3455, 'Miami'), (3190, 'New York'), (3852, 'Miami')]
# Distances:
#  {'Seattle': 0, 'San Francisco': 807, 'Los Angeles': 1188, 'Denver': 1331, 'Chicago': 2097, 'Boston': 3080, 'New York': 2884, 'Kansas City': 1930, 'Atlanta': 2794, 'Dallas': 2426, 'Houston': 2665, 'Miami': 3455}
#
# pulling New York (distance to New York = 2884) from priority queue...
#
# Is the current distance to New York (2884) greater than New York's distance (2884)? No! Let's analyze it:
# dict_items([('Boston', 214), ('Chicago', 787), ('Kansas City', 1260), ('Atlanta', 888)])
#
# distance to Boston = current_distance + weight = 2884 + 214
# thus, distance to Boston = 3098
# Is this distance better than the current estimate (3080)?
# No.
#
# distance to Chicago = current_distance + weight = 2884 + 787
# thus, distance to Chicago = 3671
# Is this distance better than the current estimate (2097)?
# No.
#
# distance to Kansas City = current_distance + weight = 2884 + 1260
# thus, distance to Kansas City = 4144
# Is this distance better than the current estimate (1930)?
# No.
#
# distance to Atlanta = current_distance + weight = 2884 + 888
# thus, distance to Atlanta = 3772
# Is this distance better than the current estimate (2794)?
# No.
# ----------------
# Priority Queue:
#  [(3080, 'Boston'), (3190, 'New York'), (3455, 'Miami'), (3852, 'Miami')]
# Distances:
#  {'Seattle': 0, 'San Francisco': 807, 'Los Angeles': 1188, 'Denver': 1331, 'Chicago': 2097, 'Boston': 3080, 'New York': 2884, 'Kansas City': 1930, 'Atlanta': 2794, 'Dallas': 2426, 'Houston': 2665, 'Miami': 3455}
#
# pulling Boston (distance to Boston = 3080) from priority queue...
#
# Is the current distance to Boston (3080) greater than Boston's distance (3080)? No! Let's analyze it:
# dict_items([('Chicago', 983), ('New York', 214)])
#
# distance to Chicago = current_distance + weight = 3080 + 983
# thus, distance to Chicago = 4063
# Is this distance better than the current estimate (2097)?
# No.
#
# distance to New York = current_distance + weight = 3080 + 214
# thus, distance to New York = 3294
# Is this distance better than the current estimate (2884)?
# No.
# ----------------
# Priority Queue:
#  [(3190, 'New York'), (3852, 'Miami'), (3455, 'Miami')]
# Distances:
#  {'Seattle': 0, 'San Francisco': 807, 'Los Angeles': 1188, 'Denver': 1331, 'Chicago': 2097, 'Boston': 3080, 'New York': 2884, 'Kansas City': 1930, 'Atlanta': 2794, 'Dallas': 2426, 'Houston': 2665, 'Miami': 3455}
#
# pulling New York (distance to New York = 3190) from priority queue...
#
# Is the current distance to New York (3190) greater than New York's distance (2884)? Yes. Move on.
# ----------------
# Priority Queue:
#  [(3455, 'Miami'), (3852, 'Miami')]
# Distances:
#  {'Seattle': 0, 'San Francisco': 807, 'Los Angeles': 1188, 'Denver': 1331, 'Chicago': 2097, 'Boston': 3080, 'New York': 2884, 'Kansas City': 1930, 'Atlanta': 2794, 'Dallas': 2426, 'Houston': 2665, 'Miami': 3455}
#
# pulling Miami (distance to Miami = 3455) from priority queue...
#
# Is the current distance to Miami (3455) greater than Miami's distance (3455)? No! Let's analyze it:
# dict_items([('Houston', 1187), ('Atlanta', 661)])
#
# distance to Houston = current_distance + weight = 3455 + 1187
# thus, distance to Houston = 4642
# Is this distance better than the current estimate (2665)?
# No.
#
# distance to Atlanta = current_distance + weight = 3455 + 661
# thus, distance to Atlanta = 4116
# Is this distance better than the current estimate (2794)?
# No.
# ----------------
# Priority Queue:
#  [(3852, 'Miami')]
# Distances:
#  {'Seattle': 0, 'San Francisco': 807, 'Los Angeles': 1188, 'Denver': 1331, 'Chicago': 2097, 'Boston': 3080, 'New York': 2884, 'Kansas City': 1930, 'Atlanta': 2794, 'Dallas': 2426, 'Houston': 2665, 'Miami': 3455}
#
# pulling Miami (distance to Miami = 3852) from priority queue...
#
# Is the current distance to Miami (3852) greater than Miami's distance (3455)? Yes. Move on.
#
#
# Result
# {'Seattle': 0, 'San Francisco': 807, 'Los Angeles': 1188, 'Denver': 1331, 'Chicago': 2097, 'Boston': 3080, 'New York': 2884, 'Kansas City': 1930, 'Atlanta': 2794, 'Dallas': 2426, 'Houston': 2665, 'Miami': 3455}
