# %% [markdown]
# Vet Clinic System - Victor Ferreira Silva
# ===========
#
# Programming for AI - HDIP in Artificial Intelligence
# ----------
#
# Requirements - Part 1 - Generate Associate Table
# -----------
# + Create a working program to demonstrate a “Vet Clinic” as a prototype.
# + There is code to generate 2 CSV files (vets and pets) with random data every time the program runs. This code must not be modified and should be included in you final Jupyter notebook or .py script
# + Pets entity has ID, Name, Species, Age (int) and Vets entity has ID, Name, Specialty
# + Randomly associate 1 vet to N pets
# + Save this data on a new CSV file called vet_pet.csv. Vets and pets have an Unique ID
#
# Requirements - Part 2 - Menu and Features
# ------------
# + view all vets
# + view all pets
# + view vets of a specialty
# + view pets of a specific species
# + find a vet by ID and list their pets
# + find a pet by ID and view its vet
# + option to close program
# + keep the program running until the user decides they want to quit.
#
# Requeriments - Don't Forget
# ---------
# + validate all inputs
# + clever comments
# + don't cheat!
#
#
# Questions:
# -------
# + _You must submit your full NetBeans project in a compressed zip file including both the code provided to you and the code produced by you. This should be a working program. No debugging will be done._ Is it correct?
# + The vets scripts may generate 2 records for a same vet name with 2 distinct specialties. Is it ok?

# %%
import random
import csv

doctorNames = ["Alvin Carpenter","Lorna Jenkins","Nisha Vang","Ashlee Owens",
        "Rojin Sparrow","Madeeha Bellamy","Ewen Stott","Franco Crouch",
        "Jensen Conroy","Clarissa Churchill","Batman","Aron Parsons",
        "Tyron Goodman","Shahzaib Petty","Julius Colley","Calista Cummings",
        "Eiliyah West","Adem Wardle","Keaton Ferry","Salman Whitley",
        "Simran Dudley","Halle Sampson","Zander Spencer","Gurveer Lutz",
        "Hasnain Mendoza","Scarlette Mohammed","Nadeem Craft","Ajay Bryan",
        "Kiera Ridley","Otto Valenzuela","Tarik Corona","Ella-Rose Choi",
        "Roland Burns","Sheena Walls","Robert Horne","Eleasha Firth",
        "Gracie Hood","Albert Cross","Domonic Keller","Kenya Hartman",
        "Luna Crosby","Isabella-Rose Hawkins","Kathryn Lindsey","Karen Diaz",
        "Gianluca Walker","Ephraim Booth","Zayan Yang","Conal Taylor",
        "Jimmie Gallegos","Ritik Moses","Lois Wong","Sylvie Yoder",
        "Romana Wagner","Kelly Hodge","Romy Cohen","Renee Park",
        "Siraj Blevins","Lexi Hendricks","Mario Easton","Aoife Wynn",
        "Devon Lowry","Mathias Russo","Fionn Cochran","Ella-Grace Hollis",
        "Karis Lane","Huseyin Sargent","Charlene Myers","Leighton Bloggs",
        "Marilyn Burks","Alessio Day","Maisha Frost","Keri Rocha","Lillie Paterson",
        "Andre Matthews","Blair Torres","Roscoe Dunne","Larissa Kinney","Camron Rees",
        "Jagdeep Sims","Sandra Wickens","Soraya Bevan","Libbi Driscoll","Shanaya Bouvet",
        "Zaynab Markham","Sinead Holland","Dougie Whelan","Rylee Hinton","Federico Ray",
        "Fatima Goodwin","Amandeep Mclean","Eleri Garza","Heath Robson","Areebah Calhoun",
        "Nour Fox","Lillie-Mae O'Neill","Margot Reyna","Ibrahim Witt","Rukhsar Roman",
        "Frida Rayner","Keir Soto","Cody Buckley"]

petNames = ["Zen","Misty","Frankie Lee Jones","Lyra","Minnie","Charlie",
            "Puck","Frankie","Pepper","Cathol","Emily","George","Jet",
            "Wilbur","Slightly","Kevin Boots Ewing","Violet","Faith","Tanner",
            "Simon","North Star","Chico","Hudson","Estrela","Lucky","Daisy",
            "Buffy","Leeloo","Zorg","Digger","Piper","Gamzee","Nepeta",
            "Cloudy","Little Bear","Bailey","Princess","Eloise","Maggie",
            "Sunbeam","Koshka","Sherman","Lellow","Cowboy","Evelyn","Wilson",
            "Pumpkin","Esco","Vinnie","Norman"]

petSpecies = ["Cat", "Dog", "Parrot", "Hamster"]
numberOfPets = random.randint(500, 1000)
numberOfDoctors = random.randint(10, 30)
f1 = open('pets.csv','w', newline='\n')
writer = csv.writer(f1)
writer.writerow(["ID","Name","Species","Age"])

for n in range(numberOfPets):
   writer.writerow([n+1001, random.choice(petNames), random.choice(petSpecies),
                    random.randint(1, 15)])

f1.close()

f1 = open('vets.csv','w', newline='\n')
writer = csv.writer(f1)
writer.writerow(["ID","Name","Specialty"])

for n in range(numberOfDoctors):
   writer.writerow([n+1001, random.choice(doctorNames), random.choice(petSpecies)])

f1.close()

# %%
class Vet:
    # simple class to model veterinarian (vet)
    def __init__(self, unique_id, name, specialty):
        self.unique_id = int(unique_id)
        self.name = name
        self.specialty = specialty    
        
        
class Pet:
    # simple class to model pet
    def __init__(self, unique_id, name, species, age, vet):        
        self.unique_id = int(unique_id)
        self.name = name
        self.species = species
        self.age = int(age)
        self.vet = vet

# %%
def get_vets_list_from_file():  
    # Returns a list of Vet instances created from CSV file.    
    file = open("vets.csv",'r')    
    lines = file.readlines()[1:]    
    vets = []
    
    for i in lines:
        line = i.split(',')        
        line[2].replace('\n','')
        
        vet = Vet(unique_id=line[0], name=line[1].strip(), specialty=line[2].strip())
        vets.append(vet)
        
    file.close()
    
    return vets   


def get_pets_list_from_file(vets):  
    # Returns a list of Vet instances created from CSV file and associates a vet
    file = open("pets.csv",'r')    
    lines = file.readlines()[1:]    
    pets = []
    
    for i in lines:
        line = i.split(',')        
        line[3].replace('\n','')        
        
        specialty = line[2]        
        vets_by_specialty = get_vets_by_specialty(vets, specialty)        
        vet_by_specialty = random.choice(vets_by_specialty)
        
        pet = Pet(unique_id=line[0], name=line[1].strip(), species=line[2].strip(), age=line[3], vet=vet_by_specialty)
        pets.append(pet)
        
    file.close()
    
    return pets  


def get_vets_by_specialty(vets, specialty):
    # filters and returns vets for a certain specialty        
    vets_by_specialty = [v for v in vets if v.specialty == specialty]        
    return vets_by_specialty


def create_vet_pet_file(pets):
    # writes the associations between vets and pets in a CSV file while loops pets list
    vet_pet = open("vet_pet.csv", "w")    
    vet_pet.write('pet.unique_id,pet.name,pet.species,pet.age,')
    vet_pet.write('vet.unique_id,vet.name,vet.specialty\n')
    
    for pet in pets:
        pet_columns = f'{pet.unique_id},{pet.name},{pet.species},{pet.age}'
        vet_columns = f'{pet.vet.unique_id},{pet.vet.name},{pet.vet.specialty}'
        vet_pet.write(f'{pet_columns},{vet_columns}\n')        
        
    vet_pet.close()

# %%
def view_all_vets(vets):
    # loops through vets list and presents every record
    print(f"\nLISTING ALL VETS:")
    for vet in vets:        
        print(f'{vet.unique_id} - {vet.name} ({vet.specialty})')     
    
    
def view_all_pets(pets):
    # loops through pets list and presents every record
    print(f"\nLISTING ALL PETS:")
    for pet in pets:        
        print(f'{pet.unique_id} - {pet.name}, {pet.age} ({pet.species})')

# %%
def get_vet_specialties(vets):
    # generates a list of specialties based on vets list
    # this approach was adopted for the sake of liability of the program, 
    # since the variable petSpecies concerns to a distinct part of the exercise
    return list(set([v.specialty.lower() for v in vets]))


def show_vet_specialties_menu(specialties):   
    # presents specialties menu
    print('\nVIEW VETS FROM SPECIFIC SPECIALTY - SPECIALTIES:')
    
    for s in specialties:
        print(f'- {s}')
        
    print(f'- <blank> - back to main menu')     
    

def get_specialty_option(vets):
    # selects and validates specialty typed by user
    specialties = get_vet_specialties(vets)
    show_vet_specialties_menu(specialties)
    
    chosen_specialty = None
    while chosen_specialty not in specialties and chosen_specialty != '':
        try:
            chosen_specialty = input('Type a specialty: ').lower().strip()
        except:
            print('\nInvalid specialty')
            pass
    
    if chosen_specialty == '':
        return;    
    
    return chosen_specialty 
    
    
def view_vets_by_specialty(vets):
    # filters and prints vets of a certain specialty
    specialty = get_specialty_option(vets)

    if specialty == None:
        return;
    
    print(f'\nVETS BY SPECIALTY ({specialty.upper()})')
    
    for v in vets:        
        if v.specialty.lower() == specialty.lower():
            print(f'{v.unique_id} - {v.name} ({v.specialty})')

# %%
def get_pet_species(pets):
    # generates a list of species based on pets list
    # this approach was adopted for the sake of liability of the program, 
    # since the variable petSpecies concerns to a distinct part of the exercise
    return list(set([p.species.lower() for p in pets]))


def show_pet_species_menu(species):   
    # presents species menu
    print('\nVIEW PETS OF A SPECIFIC SPECIES - SPECIES LIST:')
    
    for s in species:
        print(f'- {s}')
        
    print(f'- <blank> - back to main menu') 

    
def get_species_option(pets):
    # selects and validates species typed by user
    species = get_pet_species(pets)
    show_pet_species_menu(species)
    
    chosen_species = None
    while chosen_species not in species and chosen_species != '':
        try:
            chosen_species = input('Type a species: ').lower().strip()
        except:
            print('\nInvalid species')
            pass
    
    if chosen_species == '':
        return;    
    
    return chosen_species             
            
            
def view_pets_by_species(pets):
    # filters and prints pets of a certain species
    species = get_species_option(pets)
    
    if species == None:
        return;
    
    print(f'\nPETS BY SPECIES ({species.upper()})')
    
    for p in pets:        
        if p.species.lower() == species.lower():
            print(f'{p.unique_id} - {p.name}, {p.age} ({p.species})')

# %%
def view_pets_by_vet(vets, pets):
    # find a particular vet given their ID and view all pets associated to them
    print('\nFIND VET AND VIEW THEIR PETS')
    vet_id = int(input('Type Vet ID (or <blank> to go back to main menu):'))    
    vet = next((v for v in vets if v.unique_id == vet_id), None)
    
    if vet == None:
        print(f'vet id #{vet_id} cannot be found')
        return
          
    print(f'\nVET: {vet.name} ({vet.specialty})')     
    pets_by_vet = [p for p in pets if p.vet.unique_id == vet.unique_id]
    print(f'ALL PETS ASSOCIATES TO {vet.name}:')
    for p in pets_by_vet:
        print(f'{p.unique_id} - {p.name}, {p.age} ({p.species}); Vet ID: {p.vet.unique_id}') 
        
        
def find_pet_by_id(pets):
    # find a particular pet given its id and view its pet
    print('\nFIND PET AND VIEW ITS VET')
    pet_id = int(input('Type Pet ID (or <blank> to go back to main menu):'))    
    pet = next((p for p in pets if p.unique_id == pet_id), None)
    
    if pet == None:
        print(f'pet id #{pet_id} cannot be found')
        return
    
    print(f'\nPET: {pet.name}, {pet.age} ({pet.species})')
    print(f"{pet.name}'s vet is {pet.vet.name} (vet id {pet.vet.unique_id})")

# %%
def show_main_menu():
    # presents the system features
    print('\nVET CLINIC SYSTEM - MAIN MENU')
    print('1 - View All Vets')
    print('2 - View All Pets')   
    print('3 - View Vets From Specific Specialty')   
    print('4 - View Pets Of Specific Species')   
    print('5 - Find Vet And View Their Pets')   
    print('6 - Find Pet And View Its Vet')   
    print("0 - Exit Program")
    
    
def get_main_menu_option():
    # requires a menu option from user and validates it
    valid_options = [0,1,2,3,4,5,6]
    option = None
    
    while option not in valid_options:
        try:
            option = int(input('Choose your option: '))
        except:
            pass
        
    return option   

def vet_clinic():    
    # main program
    vets = get_vets_list_from_file()
    pets = get_pets_list_from_file(vets)           
    create_vet_pet_file(pets) 
    
    option = None
    
    while option != 0:
        show_main_menu()    
        option = get_main_menu_option()
        
        if option == 0:
            print('\nBye-bye!')
        if option == 1:
            view_all_vets(vets)         
        if option == 2:
            view_all_pets(pets)    
        if option == 3:
            view_vets_by_specialty(vets)
        if option == 4:
            view_pets_by_species(pets)  
        if option == 5:
            view_pets_by_vet(vets, pets)
        if option == 6:
            find_pet_by_id(pets)

# %%
vet_clinic()
# Out:
# VET CLINIC SYSTEM - MAIN MENU
# 1 - View All Vets
# 2 - View All Pets
# 3 - View Vets From Specific Specialty
# 4 - View Pets Of Specific Species
# 5 - Find Vet And View Their Pets
# 6 - Find Pet And View Its Vet
# 0 - Exit Program
# Choose your option: 1
#
# LISTING ALL VETS:
# 1001 - Lillie Paterson (Dog)
# 1002 - Shanaya Bouvet (Hamster)
# 1003 - Lillie Paterson (Dog)
# 1004 - Ephraim Booth (Parrot)
# 1005 - Shanaya Bouvet (Parrot)
# 1006 - Keri Rocha (Cat)
# 1007 - Domonic Keller (Dog)
# 1008 - Simran Dudley (Hamster)
# 1009 - Aoife Wynn (Hamster)
# 1010 - Luna Crosby (Parrot)
# 1011 - Rojin Sparrow (Hamster)
# 1012 - Clarissa Churchill (Parrot)
# 1013 - Jensen Conroy (Dog)
# 1014 - Hasnain Mendoza (Dog)
# 1015 - Federico Ray (Parrot)
# 1016 - Marilyn Burks (Dog)
# 1017 - Amandeep Mclean (Parrot)
#
# VET CLINIC SYSTEM - MAIN MENU
# 1 - View All Vets
# 2 - View All Pets
# 3 - View Vets From Specific Specialty
# 4 - View Pets Of Specific Species
# 5 - Find Vet And View Their Pets
# 6 - Find Pet And View Its Vet
# 0 - Exit Program
# Choose your option: 2
#
# LISTING ALL PETS:
# 1001 - Faith, 5 (Hamster)
# 1002 - Lyra, 11 (Cat)
# 1003 - Sherman, 12 (Hamster)
# 1004 - Norman, 15 (Hamster)
# 1005 - Pumpkin, 12 (Parrot)
# 1006 - Pumpkin, 10 (Cat)
# 1007 - Estrela, 12 (Dog)
# 1008 - Lellow, 15 (Cat)
# 1009 - North Star, 2 (Dog)
# 1010 - Bailey, 8 (Parrot)
# 1011 - Evelyn, 1 (Hamster)
# 1012 - Princess, 14 (Parrot)
# 1013 - Chico, 3 (Dog)
# 1014 - Lellow, 11 (Dog)
# 1015 - Frankie, 1 (Hamster)
# 1016 - Hudson, 15 (Hamster)
# 1017 - Frankie, 3 (Hamster)
# 1018 - Minnie, 5 (Dog)
# 1019 - Puck, 10 (Hamster)
# 1020 - Charlie, 3 (Cat)
# 1021 - Zen, 7 (Cat)
# 1022 - Digger, 4 (Hamster)
# 1023 - Esco, 3 (Cat)
# 1024 - Hudson, 5 (Cat)
# 1025 - Lellow, 14 (Hamster)
# 1026 - Pepper, 2 (Hamster)
# 1027 - Maggie, 2 (Parrot)
# 1028 - Frankie, 5 (Parrot)
# 1029 - Hudson, 14 (Dog)
# 1030 - Koshka, 2 (Parrot)
# 1031 - Simon, 12 (Parrot)
# 1032 - Piper, 11 (Hamster)
# 1033 - Simon, 9 (Parrot)
# 1034 - Lucky, 10 (Parrot)
# 1035 - Sherman, 13 (Parrot)
# 1036 - Zen, 8 (Dog)
# 1037 - Cowboy, 8 (Parrot)
# 1038 - Daisy, 6 (Parrot)
# 1039 - Esco, 7 (Hamster)
# 1040 - Esco, 11 (Dog)
# 1041 - Emily, 12 (Dog)
# 1042 - Puck, 3 (Hamster)
# 1043 - Tanner, 5 (Hamster)
# 1044 - North Star, 9 (Dog)
# 1045 - Puck, 10 (Dog)
# 1046 - Frankie Lee Jones, 3 (Cat)
# 1047 - Daisy, 7 (Parrot)
# 1048 - Norman, 8 (Parrot)
# 1049 - Lellow, 14 (Dog)
# 1050 - Lyra, 12 (Dog)
# 1051 - Hudson, 7 (Cat)
# 1052 - Esco, 15 (Parrot)
# 1053 - Charlie, 5 (Cat)
# 1054 - Simon, 15 (Cat)
# 1055 - Cathol, 15 (Parrot)
# 1056 - Lucky, 11 (Dog)
# 1057 - Zorg, 2 (Parrot)
# 1058 - Vinnie, 12 (Cat)
# 1059 - Lellow, 7 (Cat)
# 1060 - Sunbeam, 9 (Hamster)
# 1061 - Lucky, 4 (Hamster)
# 1062 - Daisy, 14 (Dog)
# 1063 - Lucky, 5 (Cat)
# 1064 - Esco, 15 (Dog)
# 1065 - Bailey, 5 (Dog)
# 1066 - Koshka, 6 (Dog)
# 1067 - Misty, 8 (Dog)
# 1068 - Piper, 1 (Dog)
# 1069 - Koshka, 5 (Parrot)
# 1070 - Zen, 9 (Hamster)
# 1071 - Lellow, 2 (Parrot)
# 1072 - Emily, 11 (Dog)
# 1073 - Sunbeam, 7 (Cat)
# 1074 - Pumpkin, 11 (Cat)
# 1075 - Sherman, 12 (Hamster)
# 1076 - Norman, 3 (Cat)
# 1077 - Frankie, 13 (Cat)
# 1078 - Maggie, 10 (Cat)
# 1079 - Faith, 8 (Dog)
# 1080 - Misty, 13 (Hamster)
# 1081 - Eloise, 6 (Parrot)
# 1082 - Esco, 5 (Cat)
# 1083 - Wilbur, 3 (Hamster)
# 1084 - Norman, 15 (Hamster)
# 1085 - Zorg, 13 (Cat)
# 1086 - Gamzee, 6 (Hamster)
# 1087 - Charlie, 12 (Cat)
# 1088 - George, 8 (Cat)
# 1089 - Wilson, 14 (Dog)
# 1090 - Cloudy, 15 (Hamster)
# 1091 - Charlie, 6 (Cat)
# 1092 - Zen, 3 (Cat)
# 1093 - Maggie, 2 (Hamster)
# 1094 - Emily, 12 (Parrot)
# 1095 - Wilbur, 14 (Parrot)
# 1096 - Princess, 10 (Dog)
# 1097 - Frankie Lee Jones, 6 (Parrot)
# 1098 - Cloudy, 5 (Parrot)
# 1099 - Sunbeam, 12 (Cat)
# 1100 - Frankie Lee Jones, 10 (Parrot)
# 1101 - Estrela, 8 (Cat)
# 1102 - Buffy, 6 (Dog)
# 1103 - Vinnie, 13 (Parrot)
# 1104 - Piper, 14 (Parrot)
# 1105 - Puck, 1 (Hamster)
# 1106 - Minnie, 6 (Hamster)
# 1107 - Chico, 11 (Cat)
# 1108 - Zorg, 4 (Cat)
# 1109 - Chico, 15 (Dog)
# 1110 - Lyra, 5 (Parrot)
# 1111 - Pumpkin, 9 (Dog)
# 1112 - Cathol, 5 (Hamster)
# 1113 - Wilson, 6 (Cat)
# 1114 - Sunbeam, 1 (Hamster)
# 1115 - Sunbeam, 4 (Hamster)
# 1116 - Faith, 5 (Cat)
# 1117 - Simon, 1 (Dog)
# 1118 - Lucky, 13 (Hamster)
# 1119 - Slightly, 7 (Cat)
# 1120 - Sherman, 8 (Cat)
# 1121 - Wilbur, 6 (Parrot)
# 1122 - Frankie, 8 (Parrot)
# 1123 - Minnie, 2 (Parrot)
# 1124 - Norman, 15 (Hamster)
# 1125 - Minnie, 12 (Parrot)
# 1126 - Princess, 9 (Dog)
# 1127 - Norman, 13 (Cat)
# 1128 - Koshka, 6 (Hamster)
# 1129 - Buffy, 10 (Hamster)
# 1130 - Lellow, 7 (Parrot)
# 1131 - Sherman, 15 (Parrot)
# 1132 - Leeloo, 7 (Cat)
# 1133 - Frankie, 2 (Cat)
# 1134 - Violet, 6 (Parrot)
# 1135 - Jet, 9 (Hamster)
# 1136 - Little Bear, 8 (Parrot)
# 1137 - Zorg, 10 (Parrot)
# 1138 - Lucky, 14 (Hamster)
# 1139 - George, 1 (Dog)
# 1140 - Sherman, 8 (Dog)
# 1141 - Princess, 1 (Hamster)
# 1142 - Pumpkin, 14 (Parrot)
# 1143 - Gamzee, 15 (Dog)
# 1144 - Princess, 1 (Cat)
# 1145 - North Star, 5 (Parrot)
# 1146 - Violet, 11 (Hamster)
# 1147 - Sunbeam, 3 (Parrot)
# 1148 - Estrela, 9 (Dog)
# 1149 - Digger, 11 (Cat)
# 1150 - Princess, 12 (Dog)
# 1151 - Pumpkin, 2 (Hamster)
# 1152 - George, 10 (Parrot)
# 1153 - George, 13 (Parrot)
# 1154 - Daisy, 13 (Dog)
# 1155 - Cloudy, 8 (Parrot)
# 1156 - Little Bear, 8 (Dog)
# 1157 - Cowboy, 3 (Hamster)
# 1158 - Evelyn, 13 (Hamster)
# 1159 - Charlie, 14 (Hamster)
# 1160 - North Star, 13 (Parrot)
# 1161 - Hudson, 14 (Hamster)
# 1162 - Pepper, 2 (Parrot)
# 1163 - Little Bear, 11 (Dog)
# 1164 - Maggie, 8 (Hamster)
# 1165 - Faith, 12 (Parrot)
# 1166 - Misty, 11 (Cat)
# 1167 - Faith, 11 (Parrot)
# 1168 - Violet, 5 (Dog)
# 1169 - Faith, 3 (Dog)
# 1170 - Norman, 9 (Dog)
# 1171 - Misty, 8 (Dog)
# 1172 - Lucky, 4 (Hamster)
# 1173 - Charlie, 5 (Parrot)
# 1174 - Koshka, 8 (Cat)
# 1175 - Evelyn, 4 (Cat)
# 1176 - Digger, 3 (Hamster)
# 1177 - Gamzee, 1 (Parrot)
# 1178 - Lucky, 7 (Hamster)
# 1179 - Buffy, 7 (Dog)
# 1180 - Faith, 4 (Hamster)
# 1181 - Sunbeam, 6 (Hamster)
# 1182 - Princess, 1 (Parrot)
# 1183 - Digger, 1 (Cat)
# 1184 - Vinnie, 8 (Cat)
# 1185 - Eloise, 1 (Parrot)
# 1186 - Minnie, 14 (Cat)
# 1187 - Daisy, 12 (Cat)
# 1188 - Violet, 4 (Cat)
# 1189 - Gamzee, 15 (Parrot)
# 1190 - Daisy, 15 (Dog)
# 1191 - George, 6 (Dog)
# 1192 - Hudson, 9 (Parrot)
# 1193 - Cowboy, 5 (Cat)
# 1194 - Estrela, 7 (Dog)
# 1195 - Piper, 12 (Dog)
# 1196 - Maggie, 15 (Dog)
# 1197 - Faith, 9 (Dog)
# 1198 - Zen, 6 (Dog)
# 1199 - Sherman, 8 (Dog)
# 1200 - Frankie, 9 (Dog)
# 1201 - Zen, 4 (Hamster)
# 1202 - Pumpkin, 10 (Cat)
# 1203 - Cowboy, 6 (Cat)
# 1204 - Emily, 9 (Dog)
# 1205 - Lyra, 1 (Cat)
# 1206 - Wilbur, 9 (Cat)
# 1207 - Jet, 2 (Cat)
# 1208 - Hudson, 5 (Parrot)
# 1209 - Cathol, 4 (Cat)
# 1210 - Simon, 15 (Parrot)
# 1211 - Maggie, 13 (Dog)
# 1212 - Evelyn, 6 (Dog)
# 1213 - Pepper, 11 (Cat)
# 1214 - Tanner, 5 (Cat)
# 1215 - Kevin Boots Ewing, 1 (Hamster)
# 1216 - Lyra, 15 (Parrot)
# 1217 - Vinnie, 7 (Parrot)
# 1218 - Chico, 2 (Parrot)
# 1219 - Pepper, 9 (Parrot)
# 1220 - Zorg, 10 (Cat)
# 1221 - Wilson, 13 (Hamster)
# 1222 - Lellow, 8 (Cat)
# 1223 - Gamzee, 13 (Cat)
# 1224 - Eloise, 10 (Hamster)
# 1225 - Cathol, 3 (Hamster)
# 1226 - Jet, 10 (Hamster)
# 1227 - Leeloo, 15 (Parrot)
# 1228 - Princess, 15 (Hamster)
# 1229 - Emily, 2 (Dog)
# 1230 - Pumpkin, 6 (Cat)
# 1231 - Pepper, 7 (Dog)
# 1232 - Esco, 4 (Hamster)
# 1233 - Buffy, 1 (Parrot)
# 1234 - Piper, 12 (Parrot)
# 1235 - Norman, 11 (Parrot)
# 1236 - North Star, 13 (Cat)
# 1237 - Zen, 5 (Hamster)
# 1238 - Lyra, 1 (Parrot)
# 1239 - Lucky, 13 (Hamster)
# 1240 - Slightly, 6 (Parrot)
# 1241 - Koshka, 2 (Parrot)
# 1242 - North Star, 8 (Parrot)
# 1243 - North Star, 13 (Cat)
# 1244 - Misty, 4 (Cat)
# 1245 - Sherman, 5 (Cat)
# 1246 - Buffy, 1 (Cat)
# 1247 - George, 3 (Dog)
# 1248 - Slightly, 5 (Cat)
# 1249 - Zen, 6 (Dog)
# 1250 - Bailey, 6 (Hamster)
# 1251 - Daisy, 10 (Dog)
# 1252 - Minnie, 2 (Parrot)
# 1253 - Puck, 5 (Cat)
# 1254 - Zorg, 7 (Hamster)
# 1255 - Simon, 13 (Parrot)
# 1256 - Simon, 3 (Dog)
# 1257 - Frankie, 2 (Hamster)
# 1258 - Evelyn, 2 (Cat)
# 1259 - Wilbur, 5 (Dog)
# 1260 - Puck, 2 (Parrot)
# 1261 - Lellow, 2 (Parrot)
# 1262 - Little Bear, 15 (Parrot)
# 1263 - Puck, 3 (Cat)
# 1264 - Violet, 3 (Hamster)
# 1265 - Jet, 6 (Parrot)
# 1266 - Jet, 2 (Dog)
# 1267 - North Star, 3 (Cat)
# 1268 - Princess, 5 (Cat)
# 1269 - Princess, 10 (Dog)
# 1270 - Nepeta, 12 (Cat)
# 1271 - Charlie, 13 (Cat)
# 1272 - Sunbeam, 5 (Dog)
# 1273 - Sherman, 3 (Hamster)
# 1274 - Pepper, 11 (Hamster)
# 1275 - Buffy, 8 (Parrot)
# 1276 - Wilson, 3 (Parrot)
# 1277 - Violet, 4 (Cat)
# 1278 - Evelyn, 7 (Cat)
# 1279 - Hudson, 14 (Dog)
# 1280 - Charlie, 3 (Parrot)
# 1281 - Maggie, 4 (Dog)
# 1282 - Chico, 15 (Parrot)
# 1283 - Cloudy, 7 (Cat)
# 1284 - Frankie Lee Jones, 4 (Hamster)
# 1285 - Princess, 6 (Cat)
# 1286 - Misty, 8 (Parrot)
# 1287 - Emily, 1 (Dog)
# 1288 - Frankie, 4 (Hamster)
# 1289 - Hudson, 14 (Cat)
# 1290 - Little Bear, 13 (Cat)
# 1291 - Hudson, 6 (Parrot)
# 1292 - North Star, 9 (Hamster)
# 1293 - Violet, 12 (Cat)
# 1294 - Lellow, 3 (Cat)
# 1295 - Vinnie, 10 (Dog)
# 1296 - Little Bear, 6 (Parrot)
# 1297 - Pepper, 3 (Cat)
# 1298 - Lyra, 3 (Dog)
# 1299 - Eloise, 14 (Hamster)
# 1300 - Frankie, 4 (Hamster)
# 1301 - Wilson, 3 (Parrot)
# 1302 - Zen, 3 (Dog)
# 1303 - Bailey, 13 (Dog)
# 1304 - Chico, 9 (Parrot)
# 1305 - Faith, 5 (Parrot)
# 1306 - Hudson, 1 (Hamster)
# 1307 - Chico, 14 (Parrot)
# 1308 - Zen, 5 (Dog)
# 1309 - Piper, 1 (Dog)
# 1310 - Eloise, 8 (Hamster)
# 1311 - Sherman, 10 (Dog)
# 1312 - Misty, 7 (Dog)
# 1313 - Princess, 5 (Cat)
# 1314 - Simon, 5 (Hamster)
# 1315 - Gamzee, 3 (Dog)
# 1316 - Bailey, 3 (Dog)
# 1317 - Gamzee, 5 (Dog)
# 1318 - Pumpkin, 7 (Cat)
# 1319 - Emily, 2 (Hamster)
# 1320 - Zen, 4 (Cat)
# 1321 - Buffy, 4 (Parrot)
# 1322 - Eloise, 10 (Hamster)
# 1323 - Estrela, 5 (Hamster)
# 1324 - Faith, 9 (Dog)
# 1325 - Leeloo, 8 (Cat)
# 1326 - Little Bear, 14 (Dog)
# 1327 - Estrela, 9 (Cat)
# 1328 - Frankie Lee Jones, 11 (Parrot)
# 1329 - Slightly, 15 (Cat)
# 1330 - North Star, 12 (Cat)
# 1331 - Gamzee, 8 (Dog)
# 1332 - Cowboy, 14 (Cat)
# 1333 - Little Bear, 9 (Parrot)
# 1334 - Sherman, 6 (Parrot)
# 1335 - Leeloo, 11 (Parrot)
# 1336 - Kevin Boots Ewing, 12 (Hamster)
# 1337 - Gamzee, 8 (Hamster)
# 1338 - Gamzee, 2 (Hamster)
# 1339 - Lucky, 6 (Dog)
# 1340 - Faith, 3 (Dog)
# 1341 - Cathol, 4 (Dog)
# 1342 - Chico, 2 (Parrot)
# 1343 - Frankie Lee Jones, 14 (Parrot)
# 1344 - Zorg, 14 (Parrot)
# 1345 - Minnie, 9 (Dog)
# 1346 - Sherman, 5 (Cat)
# 1347 - Lellow, 11 (Cat)
# 1348 - Nepeta, 6 (Cat)
# 1349 - Lellow, 7 (Cat)
# 1350 - Lellow, 10 (Hamster)
# 1351 - Koshka, 12 (Hamster)
# 1352 - Misty, 15 (Dog)
# 1353 - Slightly, 4 (Dog)
# 1354 - Evelyn, 2 (Parrot)
# 1355 - Frankie, 6 (Cat)
# 1356 - Zorg, 7 (Dog)
# 1357 - George, 8 (Hamster)
# 1358 - Emily, 13 (Cat)
# 1359 - Lellow, 6 (Cat)
# 1360 - Daisy, 14 (Hamster)
# 1361 - Leeloo, 13 (Cat)
# 1362 - Jet, 14 (Dog)
# 1363 - Eloise, 13 (Hamster)
# 1364 - Slightly, 9 (Cat)
# 1365 - Simon, 6 (Hamster)
# 1366 - Pepper, 5 (Parrot)
# 1367 - Piper, 11 (Parrot)
# 1368 - Pepper, 3 (Cat)
# 1369 - North Star, 1 (Hamster)
# 1370 - Wilbur, 2 (Cat)
# 1371 - Evelyn, 2 (Hamster)
# 1372 - Emily, 1 (Parrot)
# 1373 - Maggie, 13 (Parrot)
# 1374 - Zen, 8 (Dog)
# 1375 - Eloise, 6 (Parrot)
# 1376 - Maggie, 7 (Dog)
# 1377 - Sunbeam, 5 (Hamster)
# 1378 - Lyra, 14 (Hamster)
# 1379 - Cowboy, 8 (Parrot)
# 1380 - Tanner, 12 (Cat)
# 1381 - Chico, 12 (Parrot)
# 1382 - Lyra, 3 (Cat)
# 1383 - Lyra, 6 (Dog)
# 1384 - Frankie, 15 (Dog)
# 1385 - Pepper, 13 (Dog)
# 1386 - Digger, 3 (Cat)
# 1387 - Sherman, 8 (Dog)
# 1388 - Zorg, 15 (Cat)
# 1389 - Misty, 5 (Parrot)
# 1390 - Digger, 14 (Parrot)
# 1391 - Cloudy, 15 (Hamster)
# 1392 - Norman, 4 (Parrot)
# 1393 - Cowboy, 15 (Cat)
# 1394 - Chico, 12 (Hamster)
# 1395 - Charlie, 6 (Hamster)
# 1396 - Hudson, 15 (Parrot)
# 1397 - Pumpkin, 6 (Cat)
# 1398 - Lyra, 11 (Parrot)
# 1399 - Piper, 5 (Dog)
# 1400 - Zen, 15 (Parrot)
# 1401 - Pumpkin, 11 (Cat)
# 1402 - Buffy, 10 (Cat)
# 1403 - Charlie, 8 (Hamster)
# 1404 - Vinnie, 13 (Dog)
# 1405 - Cathol, 4 (Parrot)
# 1406 - Cowboy, 15 (Parrot)
# 1407 - Sunbeam, 1 (Parrot)
# 1408 - Maggie, 5 (Dog)
# 1409 - Cloudy, 7 (Dog)
# 1410 - Violet, 3 (Parrot)
# 1411 - Jet, 14 (Dog)
# 1412 - Buffy, 11 (Dog)
# 1413 - Pepper, 15 (Dog)
# 1414 - Daisy, 9 (Hamster)
# 1415 - Wilson, 9 (Parrot)
# 1416 - Gamzee, 6 (Dog)
# 1417 - Jet, 6 (Cat)
# 1418 - Zen, 3 (Cat)
# 1419 - Eloise, 13 (Parrot)
# 1420 - Cathol, 11 (Dog)
# 1421 - Estrela, 2 (Hamster)
# 1422 - Sherman, 7 (Cat)
# 1423 - Minnie, 8 (Dog)
# 1424 - Simon, 1 (Dog)
# 1425 - Daisy, 14 (Cat)
# 1426 - George, 15 (Hamster)
# 1427 - Piper, 11 (Cat)
# 1428 - Gamzee, 10 (Hamster)
# 1429 - Wilbur, 4 (Parrot)
# 1430 - Misty, 10 (Hamster)
# 1431 - Wilbur, 7 (Hamster)
# 1432 - North Star, 13 (Parrot)
# 1433 - Lellow, 13 (Dog)
# 1434 - Leeloo, 5 (Hamster)
# 1435 - Misty, 4 (Cat)
# 1436 - Faith, 2 (Hamster)
# 1437 - Piper, 15 (Cat)
# 1438 - Pepper, 8 (Dog)
# 1439 - Norman, 4 (Parrot)
# 1440 - Faith, 2 (Hamster)
# 1441 - Misty, 4 (Hamster)
# 1442 - Koshka, 13 (Hamster)
# 1443 - North Star, 4 (Hamster)
# 1444 - Minnie, 8 (Dog)
# 1445 - Maggie, 4 (Cat)
# 1446 - Zen, 10 (Dog)
# 1447 - Piper, 5 (Dog)
# 1448 - North Star, 5 (Dog)
# 1449 - Simon, 4 (Cat)
# 1450 - Zen, 2 (Parrot)
# 1451 - Buffy, 15 (Parrot)
# 1452 - Koshka, 15 (Cat)
# 1453 - Princess, 10 (Dog)
# 1454 - Violet, 13 (Cat)
# 1455 - Slightly, 4 (Hamster)
# 1456 - Buffy, 14 (Parrot)
# 1457 - Lucky, 4 (Parrot)
# 1458 - Wilbur, 7 (Hamster)
# 1459 - Vinnie, 11 (Parrot)
# 1460 - Little Bear, 11 (Hamster)
# 1461 - Princess, 10 (Dog)
# 1462 - Chico, 13 (Parrot)
# 1463 - Puck, 2 (Dog)
# 1464 - Maggie, 1 (Cat)
# 1465 - Tanner, 2 (Hamster)
# 1466 - North Star, 13 (Hamster)
# 1467 - Frankie Lee Jones, 6 (Dog)
# 1468 - Lucky, 7 (Dog)
# 1469 - Emily, 5 (Parrot)
# 1470 - Daisy, 12 (Parrot)
# 1471 - North Star, 11 (Dog)
# 1472 - Daisy, 13 (Hamster)
# 1473 - Esco, 11 (Dog)
# 1474 - Evelyn, 13 (Hamster)
# 1475 - Vinnie, 12 (Cat)
# 1476 - Bailey, 1 (Dog)
# 1477 - Little Bear, 4 (Hamster)
# 1478 - Digger, 2 (Cat)
# 1479 - Lyra, 1 (Cat)
# 1480 - Zorg, 11 (Hamster)
# 1481 - Maggie, 15 (Hamster)
# 1482 - North Star, 13 (Hamster)
# 1483 - Simon, 7 (Dog)
# 1484 - Nepeta, 10 (Dog)
# 1485 - Digger, 10 (Hamster)
# 1486 - Hudson, 2 (Hamster)
# 1487 - Digger, 6 (Dog)
# 1488 - Hudson, 2 (Parrot)
# 1489 - Little Bear, 14 (Cat)
# 1490 - Maggie, 1 (Parrot)
# 1491 - Sherman, 4 (Hamster)
# 1492 - Kevin Boots Ewing, 11 (Parrot)
# 1493 - Esco, 14 (Dog)
# 1494 - Faith, 10 (Hamster)
# 1495 - Pumpkin, 10 (Parrot)
# 1496 - Cathol, 2 (Dog)
# 1497 - Wilbur, 7 (Cat)
# 1498 - Lyra, 13 (Dog)
# 1499 - George, 4 (Cat)
# 1500 - Slightly, 8 (Parrot)
# 1501 - Bailey, 4 (Cat)
# 1502 - Gamzee, 6 (Parrot)
# 1503 - Bailey, 14 (Parrot)
# 1504 - George, 2 (Hamster)
# 1505 - Eloise, 10 (Dog)
# 1506 - Tanner, 14 (Parrot)
# 1507 - Cowboy, 5 (Cat)
# 1508 - Tanner, 10 (Dog)
# 1509 - Daisy, 10 (Dog)
# 1510 - Chico, 8 (Hamster)
# 1511 - Puck, 11 (Hamster)
# 1512 - North Star, 7 (Hamster)
# 1513 - Cloudy, 7 (Parrot)
# 1514 - Estrela, 7 (Hamster)
# 1515 - Frankie Lee Jones, 13 (Parrot)
# 1516 - Frankie, 6 (Hamster)
# 1517 - Pumpkin, 12 (Parrot)
# 1518 - Nepeta, 7 (Cat)
# 1519 - Frankie Lee Jones, 15 (Cat)
# 1520 - Lucky, 2 (Parrot)
# 1521 - Frankie, 7 (Dog)
# 1522 - Violet, 4 (Parrot)
# 1523 - Princess, 7 (Parrot)
# 1524 - Wilbur, 5 (Hamster)
# 1525 - Bailey, 8 (Parrot)
# 1526 - George, 7 (Cat)
# 1527 - Minnie, 3 (Parrot)
# 1528 - Cloudy, 6 (Parrot)
# 1529 - Esco, 5 (Dog)
# 1530 - Princess, 2 (Cat)
# 1531 - Emily, 9 (Dog)
# 1532 - Puck, 8 (Dog)
# 1533 - Lyra, 14 (Parrot)
# 1534 - Cathol, 12 (Parrot)
# 1535 - Wilson, 12 (Hamster)
# 1536 - Frankie, 9 (Cat)
# 1537 - Little Bear, 5 (Dog)
# 1538 - Little Bear, 15 (Parrot)
# 1539 - George, 12 (Hamster)
# 1540 - Piper, 8 (Parrot)
# 1541 - Wilbur, 15 (Hamster)
# 1542 - North Star, 10 (Cat)
# 1543 - Koshka, 8 (Cat)
# 1544 - Faith, 3 (Cat)
# 1545 - North Star, 12 (Cat)
# 1546 - Wilson, 6 (Hamster)
# 1547 - Gamzee, 3 (Parrot)
# 1548 - Lucky, 9 (Cat)
# 1549 - Little Bear, 9 (Cat)
# 1550 - Cloudy, 13 (Parrot)
# 1551 - Esco, 1 (Cat)
# 1552 - Little Bear, 3 (Cat)
# 1553 - Princess, 14 (Parrot)
# 1554 - Lellow, 11 (Hamster)
# 1555 - Faith, 7 (Parrot)
# 1556 - North Star, 13 (Cat)
# 1557 - Frankie Lee Jones, 13 (Cat)
# 1558 - Piper, 8 (Cat)
# 1559 - George, 5 (Dog)
# 1560 - Sunbeam, 1 (Cat)
# 1561 - Nepeta, 4 (Parrot)
# 1562 - Cloudy, 1 (Cat)
# 1563 - Tanner, 11 (Parrot)
# 1564 - Lyra, 11 (Parrot)
# 1565 - Bailey, 9 (Cat)
# 1566 - Frankie, 10 (Hamster)
# 1567 - Evelyn, 13 (Hamster)
# 1568 - Jet, 11 (Cat)
# 1569 - Pumpkin, 13 (Cat)
# 1570 - Norman, 2 (Cat)
# 1571 - Pumpkin, 11 (Dog)
# 1572 - George, 14 (Dog)
# 1573 - Misty, 4 (Cat)
# 1574 - Esco, 8 (Parrot)
# 1575 - Leeloo, 6 (Parrot)
# 1576 - Pumpkin, 12 (Cat)
# 1577 - Misty, 11 (Dog)
# 1578 - Esco, 15 (Dog)
# 1579 - Wilson, 13 (Parrot)
# 1580 - Sunbeam, 2 (Parrot)
# 1581 - Leeloo, 7 (Hamster)
# 1582 - Norman, 9 (Cat)
# 1583 - Digger, 2 (Parrot)
# 1584 - Kevin Boots Ewing, 11 (Hamster)
# 1585 - Maggie, 14 (Hamster)
# 1586 - Norman, 2 (Parrot)
# 1587 - Buffy, 2 (Dog)
# 1588 - Daisy, 10 (Dog)
#
# VET CLINIC SYSTEM - MAIN MENU
# 1 - View All Vets
# 2 - View All Pets
# 3 - View Vets From Specific Specialty
# 4 - View Pets Of Specific Species
# 5 - Find Vet And View Their Pets
# 6 - Find Pet And View Its Vet
# 0 - Exit Program
# Choose your option: 3
#
# VIEW VETS FROM SPECIFIC SPECIALTY - SPECIALTIES:
# - cat
# - hamster
# - parrot
# - dog
# - <blank> - back to main menu
# Type a specialty: dog
#
# VETS BY SPECIALTY (DOG)
# 1001 - Lillie Paterson (Dog)
# 1003 - Lillie Paterson (Dog)
# 1007 - Domonic Keller (Dog)
# 1013 - Jensen Conroy (Dog)
# 1014 - Hasnain Mendoza (Dog)
# 1016 - Marilyn Burks (Dog)
#
# VET CLINIC SYSTEM - MAIN MENU
# 1 - View All Vets
# 2 - View All Pets
# 3 - View Vets From Specific Specialty
# 4 - View Pets Of Specific Species
# 5 - Find Vet And View Their Pets
# 6 - Find Pet And View Its Vet
# 0 - Exit Program
# Choose your option: 4
#
# VIEW PETS OF A SPECIFIC SPECIES - SPECIES LIST:
# - cat
# - hamster
# - parrot
# - dog
# - <blank> - back to main menu
# Type a species: dog
#
# PETS BY SPECIES (DOG)
# 1007 - Estrela, 12 (Dog)
# 1009 - North Star, 2 (Dog)
# 1013 - Chico, 3 (Dog)
# 1014 - Lellow, 11 (Dog)
# 1018 - Minnie, 5 (Dog)
# 1029 - Hudson, 14 (Dog)
# 1036 - Zen, 8 (Dog)
# 1040 - Esco, 11 (Dog)
# 1041 - Emily, 12 (Dog)
# 1044 - North Star, 9 (Dog)
# 1045 - Puck, 10 (Dog)
# 1049 - Lellow, 14 (Dog)
# 1050 - Lyra, 12 (Dog)
# 1056 - Lucky, 11 (Dog)
# 1062 - Daisy, 14 (Dog)
# 1064 - Esco, 15 (Dog)
# 1065 - Bailey, 5 (Dog)
# 1066 - Koshka, 6 (Dog)
# 1067 - Misty, 8 (Dog)
# 1068 - Piper, 1 (Dog)
# 1072 - Emily, 11 (Dog)
# 1079 - Faith, 8 (Dog)
# 1089 - Wilson, 14 (Dog)
# 1096 - Princess, 10 (Dog)
# 1102 - Buffy, 6 (Dog)
# 1109 - Chico, 15 (Dog)
# 1111 - Pumpkin, 9 (Dog)
# 1117 - Simon, 1 (Dog)
# 1126 - Princess, 9 (Dog)
# 1139 - George, 1 (Dog)
# 1140 - Sherman, 8 (Dog)
# 1143 - Gamzee, 15 (Dog)
# 1148 - Estrela, 9 (Dog)
# 1150 - Princess, 12 (Dog)
# 1154 - Daisy, 13 (Dog)
# 1156 - Little Bear, 8 (Dog)
# 1163 - Little Bear, 11 (Dog)
# 1168 - Violet, 5 (Dog)
# 1169 - Faith, 3 (Dog)
# 1170 - Norman, 9 (Dog)
# 1171 - Misty, 8 (Dog)
# 1179 - Buffy, 7 (Dog)
# 1190 - Daisy, 15 (Dog)
# 1191 - George, 6 (Dog)
# 1194 - Estrela, 7 (Dog)
# 1195 - Piper, 12 (Dog)
# 1196 - Maggie, 15 (Dog)
# 1197 - Faith, 9 (Dog)
# 1198 - Zen, 6 (Dog)
# 1199 - Sherman, 8 (Dog)
# 1200 - Frankie, 9 (Dog)
# 1204 - Emily, 9 (Dog)
# 1211 - Maggie, 13 (Dog)
# 1212 - Evelyn, 6 (Dog)
# 1229 - Emily, 2 (Dog)
# 1231 - Pepper, 7 (Dog)
# 1247 - George, 3 (Dog)
# 1249 - Zen, 6 (Dog)
# 1251 - Daisy, 10 (Dog)
# 1256 - Simon, 3 (Dog)
# 1259 - Wilbur, 5 (Dog)
# 1266 - Jet, 2 (Dog)
# 1269 - Princess, 10 (Dog)
# 1272 - Sunbeam, 5 (Dog)
# 1279 - Hudson, 14 (Dog)
# 1281 - Maggie, 4 (Dog)
# 1287 - Emily, 1 (Dog)
# 1295 - Vinnie, 10 (Dog)
# 1298 - Lyra, 3 (Dog)
# 1302 - Zen, 3 (Dog)
# 1303 - Bailey, 13 (Dog)
# 1308 - Zen, 5 (Dog)
# 1309 - Piper, 1 (Dog)
# 1311 - Sherman, 10 (Dog)
# 1312 - Misty, 7 (Dog)
# 1315 - Gamzee, 3 (Dog)
# 1316 - Bailey, 3 (Dog)
# 1317 - Gamzee, 5 (Dog)
# 1324 - Faith, 9 (Dog)
# 1326 - Little Bear, 14 (Dog)
# 1331 - Gamzee, 8 (Dog)
# 1339 - Lucky, 6 (Dog)
# 1340 - Faith, 3 (Dog)
# 1341 - Cathol, 4 (Dog)
# 1345 - Minnie, 9 (Dog)
# 1352 - Misty, 15 (Dog)
# 1353 - Slightly, 4 (Dog)
# 1356 - Zorg, 7 (Dog)
# 1362 - Jet, 14 (Dog)
# 1374 - Zen, 8 (Dog)
# 1376 - Maggie, 7 (Dog)
# 1383 - Lyra, 6 (Dog)
# 1384 - Frankie, 15 (Dog)
# 1385 - Pepper, 13 (Dog)
# 1387 - Sherman, 8 (Dog)
# 1399 - Piper, 5 (Dog)
# 1404 - Vinnie, 13 (Dog)
# 1408 - Maggie, 5 (Dog)
# 1409 - Cloudy, 7 (Dog)
# 1411 - Jet, 14 (Dog)
# 1412 - Buffy, 11 (Dog)
# 1413 - Pepper, 15 (Dog)
# 1416 - Gamzee, 6 (Dog)
# 1420 - Cathol, 11 (Dog)
# 1423 - Minnie, 8 (Dog)
# 1424 - Simon, 1 (Dog)
# 1433 - Lellow, 13 (Dog)
# 1438 - Pepper, 8 (Dog)
# 1444 - Minnie, 8 (Dog)
# 1446 - Zen, 10 (Dog)
# 1447 - Piper, 5 (Dog)
# 1448 - North Star, 5 (Dog)
# 1453 - Princess, 10 (Dog)
# 1461 - Princess, 10 (Dog)
# 1463 - Puck, 2 (Dog)
# 1467 - Frankie Lee Jones, 6 (Dog)
# 1468 - Lucky, 7 (Dog)
# 1471 - North Star, 11 (Dog)
# 1473 - Esco, 11 (Dog)
# 1476 - Bailey, 1 (Dog)
# 1483 - Simon, 7 (Dog)
# 1484 - Nepeta, 10 (Dog)
# 1487 - Digger, 6 (Dog)
# 1493 - Esco, 14 (Dog)
# 1496 - Cathol, 2 (Dog)
# 1498 - Lyra, 13 (Dog)
# 1505 - Eloise, 10 (Dog)
# 1508 - Tanner, 10 (Dog)
# 1509 - Daisy, 10 (Dog)
# 1521 - Frankie, 7 (Dog)
# 1529 - Esco, 5 (Dog)
# 1531 - Emily, 9 (Dog)
# 1532 - Puck, 8 (Dog)
# 1537 - Little Bear, 5 (Dog)
# 1559 - George, 5 (Dog)
# 1571 - Pumpkin, 11 (Dog)
# 1572 - George, 14 (Dog)
# 1577 - Misty, 11 (Dog)
# 1578 - Esco, 15 (Dog)
# 1587 - Buffy, 2 (Dog)
# 1588 - Daisy, 10 (Dog)
#
# VET CLINIC SYSTEM - MAIN MENU
# 1 - View All Vets
# 2 - View All Pets
# 3 - View Vets From Specific Specialty
# 4 - View Pets Of Specific Species
# 5 - Find Vet And View Their Pets
# 6 - Find Pet And View Its Vet
# 0 - Exit Program
# Choose your option: 6
#
# FIND PET AND VIEW ITS VET
# Type Pet ID (or <blank> to go back to main menu):1578
#
# PET: Esco, 15 (Dog)
# Esco's vet is Lillie Paterson (vet id 1001)
#
# VET CLINIC SYSTEM - MAIN MENU
# 1 - View All Vets
# 2 - View All Pets
# 3 - View Vets From Specific Specialty
# 4 - View Pets Of Specific Species
# 5 - Find Vet And View Their Pets
# 6 - Find Pet And View Its Vet
# 0 - Exit Program
# Choose your option: 5
#
# FIND VET AND VIEW THEIR PETS
# Type Vet ID (or <blank> to go back to main menu):1001
#
# VET: Lillie Paterson (Dog)
# ALL PETS ASSOCIATES TO Lillie Paterson:
# 1029 - Hudson, 14 (Dog); Vet ID: 1001
# 1062 - Daisy, 14 (Dog); Vet ID: 1001
# 1196 - Maggie, 15 (Dog); Vet ID: 1001
# 1199 - Sherman, 8 (Dog); Vet ID: 1001
# 1251 - Daisy, 10 (Dog); Vet ID: 1001
# 1259 - Wilbur, 5 (Dog); Vet ID: 1001
# 1303 - Bailey, 13 (Dog); Vet ID: 1001
# 1308 - Zen, 5 (Dog); Vet ID: 1001
# 1309 - Piper, 1 (Dog); Vet ID: 1001
# 1311 - Sherman, 10 (Dog); Vet ID: 1001
# 1385 - Pepper, 13 (Dog); Vet ID: 1001
# 1399 - Piper, 5 (Dog); Vet ID: 1001
# 1416 - Gamzee, 6 (Dog); Vet ID: 1001
# 1424 - Simon, 1 (Dog); Vet ID: 1001
# 1476 - Bailey, 1 (Dog); Vet ID: 1001
# 1493 - Esco, 14 (Dog); Vet ID: 1001
# 1521 - Frankie, 7 (Dog); Vet ID: 1001
# 1571 - Pumpkin, 11 (Dog); Vet ID: 1001
# 1578 - Esco, 15 (Dog); Vet ID: 1001
#
# VET CLINIC SYSTEM - MAIN MENU
# 1 - View All Vets
# 2 - View All Pets
# 3 - View Vets From Specific Specialty
# 4 - View Pets Of Specific Species
# 5 - Find Vet And View Their Pets
# 6 - Find Pet And View Its Vet
# 0 - Exit Program
# Choose your option: 0
#
# Bye-bye!
