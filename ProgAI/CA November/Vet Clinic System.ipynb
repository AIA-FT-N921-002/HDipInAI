# %% [markdown]
# Vet Clinic System
# ===========
#
# Programming for AI - HDIP in Artificial Intelligence
# ----------
#
# Requirements - Part 1 - Generate Associate Table
# -----------
# + Create a working program to demonstrate a “Vet Clinic” as a prototype.
# + There is code to generate 2 CSV files (vets and pets) with random data every time the program runs. This code must not be modified and should be included in you final Jupyter notebook or .py script
# + Pets entity has ID, Name, Species, Age (int) and Vets entity has ID, Name, Specialty
# + Randomly associate 1 vet to N pets
# + Save this data on a new CSV file called vet_pet.csv. Vets and pets have an Unique ID
#
# Requirements - Part 2 - Menu and Features
# ------------
# + view all vets
# + view all pets
# + view vets of a specialty
# + view pets of a specific species
# + find a vet by ID and list their pets
# + find a pet by ID and view its vet
# + option to close program
# + keep the program running until the user decides they want to quit.
#
# Requeriments - Don't Forget
# ---------
# + validate all inputs
# + clever comments
# + don't cheat!
#
#
# Questions:
# -------
# + _You must submit your full NetBeans project in a compressed zip file including both the code provided to you and the code produced by you. This should be a working program. No debugging will be done._ Is it correct?
# + The vets scripts may generate 2 records for a same vet name with 2 distinct specialties. Is it ok?

# %%
import random
import csv

doctorNames = ["Alvin Carpenter","Lorna Jenkins","Nisha Vang","Ashlee Owens",
        "Rojin Sparrow","Madeeha Bellamy","Ewen Stott","Franco Crouch",
        "Jensen Conroy","Clarissa Churchill","Batman","Aron Parsons",
        "Tyron Goodman","Shahzaib Petty","Julius Colley","Calista Cummings",
        "Eiliyah West","Adem Wardle","Keaton Ferry","Salman Whitley",
        "Simran Dudley","Halle Sampson","Zander Spencer","Gurveer Lutz",
        "Hasnain Mendoza","Scarlette Mohammed","Nadeem Craft","Ajay Bryan",
        "Kiera Ridley","Otto Valenzuela","Tarik Corona","Ella-Rose Choi",
        "Roland Burns","Sheena Walls","Robert Horne","Eleasha Firth",
        "Gracie Hood","Albert Cross","Domonic Keller","Kenya Hartman",
        "Luna Crosby","Isabella-Rose Hawkins","Kathryn Lindsey","Karen Diaz",
        "Gianluca Walker","Ephraim Booth","Zayan Yang","Conal Taylor",
        "Jimmie Gallegos","Ritik Moses","Lois Wong","Sylvie Yoder",
        "Romana Wagner","Kelly Hodge","Romy Cohen","Renee Park",
        "Siraj Blevins","Lexi Hendricks","Mario Easton","Aoife Wynn",
        "Devon Lowry","Mathias Russo","Fionn Cochran","Ella-Grace Hollis",
        "Karis Lane","Huseyin Sargent","Charlene Myers","Leighton Bloggs",
        "Marilyn Burks","Alessio Day","Maisha Frost","Keri Rocha","Lillie Paterson",
        "Andre Matthews","Blair Torres","Roscoe Dunne","Larissa Kinney","Camron Rees",
        "Jagdeep Sims","Sandra Wickens","Soraya Bevan","Libbi Driscoll","Shanaya Bouvet",
        "Zaynab Markham","Sinead Holland","Dougie Whelan","Rylee Hinton","Federico Ray",
        "Fatima Goodwin","Amandeep Mclean","Eleri Garza","Heath Robson","Areebah Calhoun",
        "Nour Fox","Lillie-Mae O'Neill","Margot Reyna","Ibrahim Witt","Rukhsar Roman",
        "Frida Rayner","Keir Soto","Cody Buckley"]

petNames = ["Zen","Misty","Frankie Lee Jones","Lyra","Minnie","Charlie",
            "Puck","Frankie","Pepper","Cathol","Emily","George","Jet",
            "Wilbur","Slightly","Kevin Boots Ewing","Violet","Faith","Tanner",
            "Simon","North Star","Chico","Hudson","Estrela","Lucky","Daisy",
            "Buffy","Leeloo","Zorg","Digger","Piper","Gamzee","Nepeta",
            "Cloudy","Little Bear","Bailey","Princess","Eloise","Maggie",
            "Sunbeam","Koshka","Sherman","Lellow","Cowboy","Evelyn","Wilson",
            "Pumpkin","Esco","Vinnie","Norman"]

petSpecies = ["Cat", "Dog", "Parrot", "Hamster"]
numberOfPets = random.randint(500, 1000)
numberOfDoctors = random.randint(10, 30)
f1 = open('pets.csv','w', newline='\n')
writer = csv.writer(f1)
writer.writerow(["ID","Name","Species","Age"])

for n in range(numberOfPets):
   writer.writerow([n+1001, random.choice(petNames), random.choice(petSpecies),
                    random.randint(1, 15)])

f1.close()

f1 = open('vets.csv','w', newline='\n')
writer = csv.writer(f1)
writer.writerow(["ID","Name","Specialty"])

for n in range(numberOfDoctors):
   writer.writerow([n+1001, random.choice(doctorNames), random.choice(petSpecies)])

f1.close()

# %%
class Vet:
    # simple class to model veterinarian (vet)
    def __init__(self, unique_id, name, specialty):
        self.unique_id = int(unique_id)
        self.name = name
        self.specialty = specialty    
        
        
class Pet:
    # simple class to model pet
    def __init__(self, unique_id, name, species, age, vet):        
        self.unique_id = int(unique_id)
        self.name = name
        self.species = species
        self.age = int(age)
        self.vet = vet

# %%
def get_vets_list_from_file():  
    # Returns a list of Vet instances created from CSV file.    
    file = open("vets.csv",'r')    
    lines = file.readlines()[1:]    
    vets = []
    
    for i in lines:
        line = i.split(',')        
        line[2].replace('\n','')
        
        vet = Vet(unique_id=line[0], name=line[1].strip(), specialty=line[2].strip())
        vets.append(vet)
        
    file.close()
    
    return vets   


def get_pets_list_from_file(vets):  
    # Returns a list of Vet instances created from CSV file and associates a vet
    file = open("pets.csv",'r')    
    lines = file.readlines()[1:]    
    pets = []
    
    for i in lines:
        line = i.split(',')        
        line[3].replace('\n','')        
        
        specialty = line[2]        
        vets_by_specialty = get_vets_by_specialty(vets, specialty)        
        vet_by_specialty = random.choice(vets_by_specialty)
        
        pet = Pet(unique_id=line[0], name=line[1].strip(), species=line[2].strip(), age=line[3], vet=vet_by_specialty)
        pets.append(pet)
        
    file.close()
    
    return pets  


def get_vets_by_specialty(vets, specialty):
    # filters and returns vets for a certain specialty        
    vets_by_specialty = [v for v in vets if v.specialty == specialty]        
    return vets_by_specialty


def create_vet_pet_file(pets):
    # writes the associations between vets and pets in a CSV file while loops pets list
    vet_pet = open("vet_pet.csv", "w")    
    vet_pet.write('pet.unique_id,pet.name,pet.species,pet.age,')
    vet_pet.write('vet.unique_id,vet.name,vet.specialty\n')
    
    for pet in pets:
        pet_columns = f'{pet.unique_id},{pet.name},{pet.species},{pet.age}'
        vet_columns = f'{pet.vet.unique_id},{pet.vet.name},{pet.vet.specialty}'
        vet_pet.write(f'{pet_columns},{vet_columns}\n')        
        
    vet_pet.close()

# %%
def view_all_vets(vets):
    # loops through vets list and presents every record
    print(f"\nLISTING ALL VETS:")
    for vet in vets:        
        print(f'{vet.unique_id} - {vet.name} ({vet.specialty})')     
        
def view_all_pets(pets):
    # loops through pets list and presents every record
    print(f"\nLISTING ALL PETS:")
    for pet in pets:        
        print(f'{pet.unique_id} - {pet.name}, {pet.age} ({pet.species})')

# %%
def show_main_menu():
    # presents the system features
    print('VET CLINIC SYSTEM')
    print('1) View All Vets')
    print('2) View All Pets')   
    print('0) Exit Program')
    
    
def get_main_menu_option():
    # requires a menu option from user and validates it
    valid_options = [0,1,2]
    option = None
    
    while option not in valid_options:
        try:
            option = int(input('Choose your option: '))
        except:
            pass
        
    return option    


def vet_clinic():    
    vets = get_vets_list_from_file()
    pets = get_pets_list_from_file(vets)           
    
    try:
        file = open('vet_pet.csv')
        file.close()        
    except FileNotFoundError:        
        print('INFO: creating vet_pet.csv...')
        create_vet_pet_file(pets)     
        print('INFO: vet_pet.csv successfully created')
    
    show_main_menu()    
    option = get_main_menu_option()    
    
    if option == 0:
        print('Good bye!')
        return;    
    
    if option == 1:
        view_all_vets(vets)         
    if option == 2:
        view_all_pets(pets)

# %%
vet_clinic()
# Out:
# VET CLINIC SYSTEM
# 1) View All Vets
# 2) View All Pets
# 0) Exit Program
# Choose your option: 2
#
# vet_set.csv was succesfully created.
#
#
# LISTING ALL PETS:
# 1001 - Esco, 5 (Parrot)
# 1002 - Tanner, 13 (Parrot)
# 1003 - Koshka, 8 (Dog)
# 1004 - Chico, 13 (Cat)
# 1005 - Tanner, 10 (Hamster)
# 1006 - Charlie, 8 (Cat)
# 1007 - Nepeta, 3 (Parrot)
# 1008 - Wilson, 14 (Hamster)
# 1009 - Faith, 9 (Cat)
# 1010 - Violet, 9 (Cat)
# 1011 - George, 2 (Dog)
# 1012 - Zen, 7 (Parrot)
# 1013 - Slightly, 3 (Cat)
# 1014 - Charlie, 2 (Cat)
# 1015 - Simon, 8 (Hamster)
# 1016 - Evelyn, 12 (Parrot)
# 1017 - Vinnie, 3 (Hamster)
# 1018 - George, 11 (Cat)
# 1019 - Princess, 10 (Parrot)
# 1020 - Evelyn, 6 (Parrot)
# 1021 - Hudson, 1 (Hamster)
# 1022 - Lyra, 15 (Hamster)
# 1023 - Zen, 1 (Parrot)
# 1024 - Digger, 3 (Hamster)
# 1025 - Nepeta, 2 (Dog)
# 1026 - Nepeta, 4 (Cat)
# 1027 - Kevin Boots Ewing, 5 (Hamster)
# 1028 - Little Bear, 13 (Hamster)
# 1029 - Cloudy, 14 (Parrot)
# 1030 - Piper, 6 (Dog)
# 1031 - Emily, 14 (Parrot)
# 1032 - Lucky, 1 (Dog)
# 1033 - Lyra, 13 (Cat)
# 1034 - Sherman, 3 (Parrot)
# 1035 - Misty, 15 (Hamster)
# 1036 - Estrela, 14 (Parrot)
# 1037 - Emily, 11 (Hamster)
# 1038 - Bailey, 14 (Parrot)
# 1039 - Violet, 5 (Cat)
# 1040 - Tanner, 8 (Cat)
# 1041 - Little Bear, 2 (Dog)
# 1042 - Zen, 8 (Hamster)
# 1043 - Princess, 9 (Parrot)
# 1044 - Chico, 14 (Cat)
# 1045 - Zen, 12 (Parrot)
# 1046 - Lellow, 6 (Hamster)
# 1047 - Violet, 5 (Parrot)
# 1048 - Sunbeam, 12 (Dog)
# 1049 - Frankie Lee Jones, 11 (Dog)
# 1050 - Zen, 3 (Dog)
# 1051 - Cloudy, 4 (Hamster)
# 1052 - Vinnie, 4 (Parrot)
# 1053 - Faith, 15 (Parrot)
# 1054 - Tanner, 8 (Parrot)
# 1055 - Norman, 10 (Dog)
# 1056 - Emily, 8 (Cat)
# 1057 - Digger, 14 (Dog)
# 1058 - Hudson, 13 (Dog)
# 1059 - Simon, 6 (Dog)
# 1060 - Misty, 13 (Parrot)
# 1061 - Esco, 2 (Hamster)
# 1062 - Puck, 11 (Hamster)
# 1063 - Estrela, 5 (Dog)
# 1064 - Eloise, 5 (Cat)
# 1065 - George, 7 (Parrot)
# 1066 - George, 11 (Dog)
# 1067 - Evelyn, 6 (Parrot)
# 1068 - Cloudy, 7 (Cat)
# 1069 - Vinnie, 9 (Dog)
# 1070 - Evelyn, 11 (Hamster)
# 1071 - Frankie Lee Jones, 10 (Hamster)
# 1072 - Lucky, 14 (Dog)
# 1073 - Pumpkin, 2 (Hamster)
# 1074 - Zen, 3 (Hamster)
# 1075 - Esco, 9 (Dog)
# 1076 - Leeloo, 10 (Dog)
# 1077 - Pumpkin, 5 (Parrot)
# 1078 - Pumpkin, 7 (Parrot)
# 1079 - Estrela, 1 (Hamster)
# 1080 - Zorg, 9 (Hamster)
# 1081 - Wilbur, 1 (Parrot)
# 1082 - Zorg, 5 (Dog)
# 1083 - Slightly, 2 (Dog)
# 1084 - Wilbur, 11 (Parrot)
# 1085 - Evelyn, 14 (Cat)
# 1086 - Puck, 14 (Hamster)
# 1087 - Chico, 13 (Parrot)
# 1088 - Pepper, 9 (Parrot)
# 1089 - Frankie, 6 (Parrot)
# 1090 - Chico, 15 (Dog)
# 1091 - Sunbeam, 11 (Dog)
# 1092 - Charlie, 15 (Parrot)
# 1093 - Norman, 1 (Cat)
# 1094 - Frankie, 4 (Hamster)
# 1095 - Tanner, 9 (Dog)
# 1096 - Lyra, 9 (Dog)
# 1097 - Frankie Lee Jones, 2 (Cat)
# 1098 - Puck, 4 (Cat)
# 1099 - Norman, 6 (Parrot)
# 1100 - Pepper, 7 (Cat)
# 1101 - Vinnie, 2 (Cat)
# 1102 - Nepeta, 6 (Hamster)
# 1103 - Cloudy, 12 (Dog)
# 1104 - Cloudy, 15 (Dog)
# 1105 - Leeloo, 8 (Cat)
# 1106 - Chico, 5 (Parrot)
# 1107 - Estrela, 15 (Hamster)
# 1108 - Violet, 3 (Cat)
# 1109 - Leeloo, 15 (Cat)
# 1110 - Estrela, 3 (Dog)
# 1111 - Tanner, 9 (Hamster)
# 1112 - Cathol, 1 (Cat)
# 1113 - Buffy, 4 (Cat)
# 1114 - Pumpkin, 15 (Dog)
# 1115 - Puck, 6 (Cat)
# 1116 - Little Bear, 9 (Dog)
# 1117 - Jet, 1 (Dog)
# 1118 - Little Bear, 5 (Hamster)
# 1119 - Princess, 10 (Cat)
# 1120 - Cathol, 1 (Parrot)
# 1121 - Tanner, 12 (Hamster)
# 1122 - Emily, 4 (Cat)
# 1123 - Misty, 3 (Dog)
# 1124 - Cowboy, 12 (Hamster)
# 1125 - Cloudy, 6 (Hamster)
# 1126 - Simon, 10 (Dog)
# 1127 - Wilbur, 8 (Dog)
# 1128 - Sherman, 10 (Cat)
# 1129 - Simon, 9 (Dog)
# 1130 - Evelyn, 7 (Parrot)
# 1131 - Nepeta, 7 (Cat)
# 1132 - Gamzee, 12 (Dog)
# 1133 - Little Bear, 8 (Parrot)
# 1134 - Koshka, 15 (Dog)
# 1135 - Cloudy, 4 (Parrot)
# 1136 - Nepeta, 7 (Parrot)
# 1137 - Sunbeam, 5 (Dog)
# 1138 - Wilson, 4 (Cat)
# 1139 - Princess, 6 (Dog)
# 1140 - Estrela, 11 (Hamster)
# 1141 - George, 4 (Hamster)
# 1142 - Puck, 1 (Cat)
# 1143 - Lucky, 1 (Dog)
# 1144 - Jet, 2 (Dog)
# 1145 - Evelyn, 1 (Hamster)
# 1146 - Wilbur, 15 (Parrot)
# 1147 - Cloudy, 9 (Dog)
# 1148 - Norman, 11 (Dog)
# 1149 - Bailey, 4 (Cat)
# 1150 - Charlie, 14 (Cat)
# 1151 - Lucky, 4 (Cat)
# 1152 - Piper, 13 (Cat)
# 1153 - Cathol, 11 (Parrot)
# 1154 - Esco, 8 (Dog)
# 1155 - Faith, 13 (Dog)
# 1156 - Puck, 12 (Parrot)
# 1157 - Pepper, 9 (Dog)
# 1158 - North Star, 2 (Parrot)
# 1159 - Cloudy, 5 (Dog)
# 1160 - Tanner, 1 (Hamster)
# 1161 - Maggie, 3 (Parrot)
# 1162 - Misty, 1 (Dog)
# 1163 - Jet, 15 (Cat)
# 1164 - Norman, 10 (Cat)
# 1165 - Faith, 7 (Parrot)
# 1166 - Koshka, 1 (Cat)
# 1167 - Wilbur, 10 (Parrot)
# 1168 - Faith, 1 (Dog)
# 1169 - Pumpkin, 3 (Cat)
# 1170 - Daisy, 11 (Parrot)
# 1171 - Koshka, 13 (Dog)
# 1172 - Pumpkin, 12 (Dog)
# 1173 - Vinnie, 13 (Parrot)
# 1174 - Misty, 9 (Dog)
# 1175 - Daisy, 3 (Cat)
# 1176 - Esco, 5 (Cat)
# 1177 - Koshka, 1 (Parrot)
# 1178 - Cloudy, 14 (Cat)
# 1179 - Minnie, 4 (Hamster)
# 1180 - Cathol, 3 (Hamster)
# 1181 - Nepeta, 13 (Cat)
# 1182 - Wilbur, 3 (Parrot)
# 1183 - Eloise, 8 (Cat)
# 1184 - Tanner, 14 (Parrot)
# 1185 - Gamzee, 3 (Hamster)
# 1186 - Norman, 9 (Cat)
# 1187 - Koshka, 11 (Hamster)
# 1188 - Wilson, 11 (Cat)
# 1189 - Cowboy, 3 (Parrot)
# 1190 - George, 13 (Cat)
# 1191 - Koshka, 4 (Hamster)
# 1192 - Misty, 8 (Parrot)
# 1193 - Cowboy, 10 (Cat)
# 1194 - Wilson, 13 (Parrot)
# 1195 - Vinnie, 8 (Parrot)
# 1196 - Little Bear, 3 (Cat)
# 1197 - Vinnie, 4 (Cat)
# 1198 - Digger, 4 (Cat)
# 1199 - Pumpkin, 15 (Cat)
# 1200 - Koshka, 15 (Dog)
# 1201 - Puck, 2 (Hamster)
# 1202 - Cowboy, 5 (Hamster)
# 1203 - Emily, 9 (Parrot)
# 1204 - Slightly, 12 (Hamster)
# 1205 - Lellow, 1 (Parrot)
# 1206 - Nepeta, 11 (Parrot)
# 1207 - Cloudy, 4 (Cat)
# 1208 - Eloise, 4 (Hamster)
# 1209 - Slightly, 1 (Hamster)
# 1210 - Pumpkin, 8 (Parrot)
# 1211 - Lucky, 7 (Hamster)
# 1212 - Cowboy, 1 (Cat)
# 1213 - Faith, 14 (Parrot)
# 1214 - Piper, 12 (Parrot)
# 1215 - Zorg, 1 (Parrot)
# 1216 - Vinnie, 5 (Hamster)
# 1217 - Buffy, 4 (Hamster)
# 1218 - Leeloo, 2 (Hamster)
# 1219 - Frankie Lee Jones, 4 (Dog)
# 1220 - Misty, 14 (Dog)
# 1221 - Nepeta, 8 (Parrot)
# 1222 - Koshka, 14 (Dog)
# 1223 - Piper, 9 (Cat)
# 1224 - Koshka, 14 (Parrot)
# 1225 - Pumpkin, 8 (Dog)
# 1226 - Tanner, 2 (Dog)
# 1227 - Frankie, 7 (Parrot)
# 1228 - Hudson, 6 (Parrot)
# 1229 - Slightly, 3 (Parrot)
# 1230 - Chico, 10 (Parrot)
# 1231 - George, 15 (Parrot)
# 1232 - Wilbur, 14 (Cat)
# 1233 - North Star, 14 (Parrot)
# 1234 - Lellow, 3 (Cat)
# 1235 - Gamzee, 13 (Dog)
# 1236 - Bailey, 15 (Dog)
# 1237 - Jet, 15 (Dog)
# 1238 - Buffy, 1 (Parrot)
# 1239 - George, 15 (Parrot)
# 1240 - Little Bear, 2 (Cat)
# 1241 - Daisy, 12 (Parrot)
# 1242 - Zorg, 15 (Cat)
# 1243 - Bailey, 14 (Parrot)
# 1244 - Slightly, 12 (Dog)
# 1245 - Norman, 4 (Parrot)
# 1246 - Cowboy, 12 (Parrot)
# 1247 - Misty, 9 (Dog)
# 1248 - Lellow, 6 (Dog)
# 1249 - North Star, 13 (Hamster)
# 1250 - Norman, 3 (Cat)
# 1251 - Cathol, 12 (Dog)
# 1252 - Violet, 6 (Hamster)
# 1253 - Wilbur, 3 (Dog)
# 1254 - Kevin Boots Ewing, 15 (Parrot)
# 1255 - Tanner, 7 (Cat)
# 1256 - Minnie, 15 (Hamster)
# 1257 - Buffy, 6 (Hamster)
# 1258 - Estrela, 5 (Hamster)
# 1259 - Wilson, 12 (Hamster)
# 1260 - Wilbur, 6 (Parrot)
# 1261 - Puck, 2 (Parrot)
# 1262 - Chico, 8 (Parrot)
# 1263 - Cloudy, 6 (Cat)
# 1264 - Piper, 14 (Dog)
# 1265 - Piper, 14 (Cat)
# 1266 - Faith, 13 (Dog)
# 1267 - Frankie, 4 (Dog)
# 1268 - Violet, 2 (Hamster)
# 1269 - Estrela, 4 (Dog)
# 1270 - Puck, 6 (Parrot)
# 1271 - Lucky, 11 (Hamster)
# 1272 - Emily, 10 (Dog)
# 1273 - Sherman, 15 (Parrot)
# 1274 - Cowboy, 2 (Dog)
# 1275 - Eloise, 12 (Hamster)
# 1276 - Slightly, 1 (Dog)
# 1277 - Puck, 8 (Cat)
# 1278 - Koshka, 12 (Hamster)
# 1279 - Violet, 7 (Cat)
# 1280 - Sunbeam, 15 (Parrot)
# 1281 - Frankie Lee Jones, 11 (Hamster)
# 1282 - Evelyn, 14 (Dog)
# 1283 - Puck, 11 (Hamster)
# 1284 - Piper, 8 (Hamster)
# 1285 - Charlie, 7 (Hamster)
# 1286 - Misty, 10 (Parrot)
# 1287 - Nepeta, 7 (Dog)
# 1288 - Lyra, 6 (Hamster)
# 1289 - Hudson, 6 (Hamster)
# 1290 - Bailey, 14 (Parrot)
# 1291 - Norman, 10 (Hamster)
# 1292 - Lucky, 4 (Hamster)
# 1293 - Kevin Boots Ewing, 6 (Cat)
# 1294 - George, 6 (Dog)
# 1295 - Chico, 10 (Cat)
# 1296 - Lyra, 8 (Hamster)
# 1297 - Little Bear, 11 (Dog)
# 1298 - Lellow, 6 (Cat)
# 1299 - Misty, 4 (Parrot)
# 1300 - Hudson, 11 (Dog)
# 1301 - Pumpkin, 13 (Cat)
# 1302 - Vinnie, 9 (Hamster)
# 1303 - Faith, 15 (Cat)
# 1304 - Digger, 6 (Hamster)
# 1305 - Princess, 15 (Hamster)
# 1306 - Pepper, 5 (Hamster)
# 1307 - Maggie, 10 (Parrot)
# 1308 - Estrela, 6 (Parrot)
# 1309 - Leeloo, 9 (Cat)
# 1310 - Digger, 10 (Hamster)
# 1311 - Slightly, 1 (Parrot)
# 1312 - Frankie Lee Jones, 7 (Dog)
# 1313 - Lellow, 12 (Dog)
# 1314 - Eloise, 10 (Hamster)
# 1315 - Wilbur, 13 (Dog)
# 1316 - Frankie, 6 (Hamster)
# 1317 - Cowboy, 13 (Cat)
# 1318 - Bailey, 11 (Dog)
# 1319 - Bailey, 2 (Parrot)
# 1320 - Pumpkin, 1 (Cat)
# 1321 - Wilbur, 14 (Parrot)
# 1322 - Lyra, 2 (Hamster)
# 1323 - Evelyn, 15 (Dog)
# 1324 - Leeloo, 10 (Cat)
# 1325 - Norman, 7 (Dog)
# 1326 - Digger, 13 (Dog)
# 1327 - Chico, 7 (Dog)
# 1328 - Leeloo, 9 (Cat)
# 1329 - Daisy, 4 (Parrot)
# 1330 - Jet, 11 (Hamster)
# 1331 - Nepeta, 2 (Dog)
# 1332 - Piper, 4 (Parrot)
# 1333 - Chico, 11 (Hamster)
# 1334 - Lellow, 14 (Parrot)
# 1335 - Pumpkin, 4 (Parrot)
# 1336 - Little Bear, 13 (Hamster)
# 1337 - Zen, 13 (Hamster)
# 1338 - Digger, 15 (Dog)
# 1339 - Lucky, 13 (Dog)
# 1340 - Esco, 9 (Dog)
# 1341 - Cathol, 5 (Parrot)
# 1342 - Koshka, 4 (Cat)
# 1343 - Piper, 12 (Hamster)
# 1344 - Slightly, 3 (Parrot)
# 1345 - Zen, 10 (Cat)
# 1346 - Violet, 2 (Cat)
# 1347 - Leeloo, 1 (Parrot)
# 1348 - Maggie, 13 (Parrot)
# 1349 - Jet, 14 (Cat)
# 1350 - Puck, 3 (Hamster)
# 1351 - Zen, 12 (Dog)
# 1352 - Piper, 12 (Parrot)
# 1353 - Zen, 8 (Parrot)
# 1354 - Princess, 7 (Parrot)
# 1355 - Zorg, 8 (Parrot)
# 1356 - Sherman, 13 (Cat)
# 1357 - Kevin Boots Ewing, 10 (Parrot)
# 1358 - Cowboy, 14 (Dog)
# 1359 - Maggie, 10 (Hamster)
# 1360 - Piper, 13 (Dog)
# 1361 - Daisy, 6 (Parrot)
# 1362 - Princess, 14 (Cat)
# 1363 - Piper, 4 (Parrot)
# 1364 - Faith, 15 (Parrot)
# 1365 - Kevin Boots Ewing, 5 (Dog)
# 1366 - Buffy, 10 (Cat)
# 1367 - Esco, 12 (Cat)
# 1368 - Simon, 15 (Cat)
# 1369 - Zorg, 6 (Parrot)
# 1370 - Minnie, 15 (Hamster)
# 1371 - Frankie, 13 (Cat)
# 1372 - Chico, 7 (Cat)
# 1373 - Cathol, 15 (Hamster)
# 1374 - Piper, 6 (Parrot)
# 1375 - Nepeta, 12 (Hamster)
# 1376 - Simon, 6 (Parrot)
# 1377 - Jet, 1 (Hamster)
# 1378 - Norman, 13 (Hamster)
# 1379 - Buffy, 13 (Hamster)
# 1380 - Lyra, 9 (Parrot)
# 1381 - Zen, 12 (Cat)
# 1382 - Sherman, 4 (Parrot)
# 1383 - Vinnie, 12 (Hamster)
# 1384 - Nepeta, 2 (Parrot)
# 1385 - Daisy, 13 (Parrot)
# 1386 - Digger, 9 (Dog)
# 1387 - George, 14 (Hamster)
# 1388 - Eloise, 1 (Hamster)
# 1389 - North Star, 12 (Dog)
# 1390 - Chico, 6 (Cat)
# 1391 - Piper, 7 (Hamster)
# 1392 - Princess, 7 (Cat)
# 1393 - Lucky, 4 (Parrot)
# 1394 - Lyra, 10 (Cat)
# 1395 - George, 7 (Parrot)
# 1396 - Hudson, 1 (Cat)
# 1397 - Emily, 9 (Parrot)
# 1398 - Frankie, 2 (Parrot)
# 1399 - Bailey, 1 (Hamster)
# 1400 - Buffy, 11 (Hamster)
# 1401 - Sunbeam, 8 (Hamster)
# 1402 - Lellow, 5 (Cat)
# 1403 - Frankie Lee Jones, 8 (Hamster)
# 1404 - Koshka, 5 (Cat)
# 1405 - Norman, 9 (Parrot)
# 1406 - Nepeta, 7 (Hamster)
# 1407 - Cowboy, 6 (Cat)
# 1408 - Daisy, 7 (Hamster)
# 1409 - Violet, 14 (Dog)
# 1410 - Estrela, 14 (Parrot)
# 1411 - Violet, 12 (Parrot)
# 1412 - Sherman, 7 (Dog)
# 1413 - Frankie, 13 (Cat)
# 1414 - Pepper, 4 (Parrot)
# 1415 - Nepeta, 7 (Hamster)
# 1416 - Nepeta, 1 (Dog)
# 1417 - Slightly, 1 (Cat)
# 1418 - Jet, 3 (Cat)
# 1419 - Buffy, 7 (Cat)
# 1420 - Little Bear, 13 (Dog)
# 1421 - Frankie, 1 (Hamster)
# 1422 - Pumpkin, 5 (Dog)
# 1423 - Jet, 7 (Parrot)
# 1424 - Puck, 6 (Dog)
# 1425 - Evelyn, 13 (Hamster)
# 1426 - Nepeta, 15 (Cat)
# 1427 - Cathol, 5 (Cat)
# 1428 - Jet, 4 (Hamster)
# 1429 - Pepper, 11 (Dog)
# 1430 - Nepeta, 1 (Cat)
# 1431 - Wilson, 12 (Dog)
# 1432 - Misty, 2 (Hamster)
# 1433 - Digger, 10 (Parrot)
# 1434 - Hudson, 11 (Dog)
# 1435 - Sunbeam, 11 (Hamster)
# 1436 - Jet, 13 (Hamster)
# 1437 - Daisy, 8 (Dog)
# 1438 - Princess, 8 (Dog)
# 1439 - Estrela, 12 (Hamster)
# 1440 - Frankie, 9 (Parrot)
# 1441 - Cathol, 9 (Cat)
# 1442 - Pumpkin, 9 (Parrot)
# 1443 - Jet, 15 (Cat)
# 1444 - Hudson, 6 (Dog)
# 1445 - Buffy, 14 (Cat)
# 1446 - Frankie, 12 (Parrot)
# 1447 - Koshka, 8 (Cat)
# 1448 - Chico, 9 (Parrot)
# 1449 - Cloudy, 12 (Dog)
# 1450 - Zen, 13 (Hamster)
# 1451 - Gamzee, 7 (Parrot)
# 1452 - Bailey, 14 (Dog)
# 1453 - Digger, 9 (Hamster)
# 1454 - Norman, 6 (Cat)
# 1455 - Estrela, 10 (Dog)
# 1456 - Little Bear, 10 (Hamster)
# 1457 - Little Bear, 11 (Dog)
# 1458 - Lellow, 15 (Cat)
# 1459 - Misty, 10 (Cat)
# 1460 - Zen, 5 (Dog)
# 1461 - Estrela, 1 (Hamster)
# 1462 - Maggie, 10 (Parrot)
# 1463 - Simon, 7 (Cat)
# 1464 - Charlie, 2 (Hamster)
# 1465 - Esco, 7 (Parrot)
# 1466 - Cloudy, 2 (Dog)
# 1467 - Vinnie, 2 (Cat)
# 1468 - Estrela, 9 (Parrot)
# 1469 - Nepeta, 10 (Hamster)
# 1470 - Violet, 15 (Cat)
# 1471 - Lellow, 12 (Cat)
# 1472 - Cowboy, 6 (Parrot)
# 1473 - Frankie Lee Jones, 10 (Hamster)
# 1474 - Piper, 11 (Cat)
# 1475 - Cowboy, 14 (Parrot)
# 1476 - Leeloo, 2 (Cat)
# 1477 - Frankie, 2 (Dog)
# 1478 - Gamzee, 10 (Hamster)
# 1479 - Piper, 3 (Parrot)
# 1480 - Wilbur, 6 (Hamster)
# 1481 - Frankie Lee Jones, 4 (Hamster)
# 1482 - Buffy, 6 (Dog)
# 1483 - Sunbeam, 10 (Parrot)
# 1484 - Gamzee, 2 (Parrot)
# 1485 - Zorg, 5 (Dog)
# 1486 - Tanner, 13 (Cat)
# 1487 - Eloise, 11 (Hamster)
# 1488 - Bailey, 1 (Dog)
# 1489 - Zorg, 15 (Dog)
# 1490 - Simon, 15 (Hamster)
# 1491 - Frankie, 7 (Cat)
# 1492 - Puck, 3 (Cat)
# 1493 - Eloise, 9 (Parrot)
# 1494 - Lucky, 12 (Parrot)
# 1495 - Maggie, 1 (Cat)
# 1496 - Evelyn, 1 (Hamster)
# 1497 - Koshka, 1 (Cat)
# 1498 - George, 10 (Parrot)
# 1499 - Lyra, 15 (Dog)
# 1500 - Minnie, 15 (Cat)
# 1501 - Eloise, 14 (Dog)
# 1502 - Pumpkin, 5 (Dog)
# 1503 - Little Bear, 10 (Dog)
# 1504 - Lucky, 2 (Cat)
# 1505 - Pepper, 2 (Hamster)
# 1506 - Sunbeam, 10 (Cat)
# 1507 - Faith, 12 (Dog)
# 1508 - Lyra, 3 (Parrot)
# 1509 - Emily, 1 (Hamster)
# 1510 - Misty, 3 (Parrot)
# 1511 - Faith, 7 (Dog)
# 1512 - Sunbeam, 13 (Hamster)
# 1513 - Minnie, 9 (Hamster)
# 1514 - Piper, 3 (Hamster)
# 1515 - Wilson, 9 (Cat)
# 1516 - Pumpkin, 13 (Hamster)
# 1517 - Eloise, 6 (Parrot)
# 1518 - Cloudy, 3 (Cat)
# 1519 - Violet, 13 (Cat)
# 1520 - Daisy, 13 (Dog)
# 1521 - Slightly, 14 (Parrot)
# 1522 - Princess, 3 (Parrot)
# 1523 - Jet, 10 (Dog)
# 1524 - Wilson, 10 (Hamster)
# 1525 - Sunbeam, 15 (Hamster)
# 1526 - George, 2 (Hamster)
# 1527 - Puck, 3 (Hamster)
# 1528 - Minnie, 4 (Dog)
# 1529 - Charlie, 14 (Hamster)
# 1530 - Frankie Lee Jones, 8 (Parrot)
# 1531 - Zen, 5 (Cat)
# 1532 - Bailey, 14 (Cat)
# 1533 - Pepper, 3 (Cat)
# 1534 - Pumpkin, 4 (Parrot)
# 1535 - Lyra, 14 (Dog)
# 1536 - Piper, 4 (Dog)
# 1537 - Gamzee, 1 (Parrot)
# 1538 - Lucky, 12 (Hamster)
# 1539 - Cowboy, 6 (Cat)
# 1540 - Cloudy, 4 (Cat)
# 1541 - Sunbeam, 10 (Hamster)
# 1542 - Piper, 13 (Parrot)
# 1543 - Cowboy, 13 (Hamster)
# 1544 - Zen, 8 (Hamster)
# 1545 - Slightly, 8 (Dog)
# 1546 - Emily, 11 (Cat)
# 1547 - Hudson, 13 (Parrot)
# 1548 - Buffy, 1 (Parrot)
# 1549 - Koshka, 9 (Hamster)
# 1550 - Eloise, 2 (Parrot)
# 1551 - Nepeta, 6 (Dog)
# 1552 - Estrela, 8 (Parrot)
# 1553 - Evelyn, 8 (Parrot)
# 1554 - Kevin Boots Ewing, 11 (Dog)
# 1555 - Simon, 6 (Cat)
# 1556 - Little Bear, 10 (Dog)
# 1557 - Sunbeam, 1 (Hamster)
# 1558 - Evelyn, 14 (Dog)
# 1559 - Maggie, 2 (Parrot)
# 1560 - Little Bear, 3 (Dog)
# 1561 - Sunbeam, 13 (Dog)
# 1562 - Gamzee, 14 (Dog)
# 1563 - Frankie, 8 (Hamster)
# 1564 - George, 11 (Dog)
# 1565 - Lellow, 1 (Hamster)
# 1566 - Slightly, 1 (Dog)
# 1567 - Zorg, 9 (Cat)
# 1568 - Violet, 2 (Dog)
# 1569 - Sherman, 14 (Dog)
# 1570 - Bailey, 13 (Cat)
# 1571 - Misty, 1 (Hamster)
# 1572 - Frankie Lee Jones, 5 (Cat)
# 1573 - Cowboy, 2 (Dog)
# 1574 - Princess, 14 (Hamster)
# 1575 - Sunbeam, 14 (Cat)
# 1576 - Buffy, 2 (Dog)
# 1577 - Tanner, 2 (Dog)
# 1578 - Kevin Boots Ewing, 6 (Hamster)
# 1579 - Zorg, 9 (Hamster)
# 1580 - Koshka, 14 (Parrot)
# 1581 - Minnie, 12 (Cat)
# 1582 - Faith, 15 (Parrot)
# 1583 - Buffy, 4 (Hamster)
# 1584 - Wilbur, 4 (Cat)
# 1585 - North Star, 13 (Dog)
# 1586 - Sherman, 15 (Dog)
# 1587 - Misty, 13 (Dog)
# 1588 - Koshka, 5 (Parrot)
# 1589 - Lyra, 14 (Dog)
