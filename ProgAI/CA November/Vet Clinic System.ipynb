# %% [markdown]
# Vet Clinic System - Victor Ferreira Silva
# ===========
#
# Programming for AI - HDIP in Artificial Intelligence
# ----------
#
# Requirements - Part 1 - Generate Associate Table
# -----------
# + Create a working program to demonstrate a “Vet Clinic” as a prototype.
# + There is code to generate 2 CSV files (vets and pets) with random data every time the program runs. This code must not be modified and should be included in you final Jupyter notebook or .py script
# + Pets entity has ID, Name, Species, Age (int) and Vets entity has ID, Name, Specialty
# + Randomly associate 1 vet to N pets
# + Save this data on a new CSV file called vet_pet.csv. Vets and pets have an Unique ID
#
# Requirements - Part 2 - Menu and Features
# ------------
# + view all vets
# + view all pets
# + view vets of a specialty
# + view pets of a specific species
# + find a vet by ID and list their pets
# + find a pet by ID and view its vet
# + option to close program
# + keep the program running until the user decides they want to quit.
#
# Requeriments - Don't Forget
# ---------
# + validate all inputs
# + clever comments
# + don't cheat!
#
#
# Questions:
# -------
# + _You must submit your full NetBeans project in a compressed zip file including both the code provided to you and the code produced by you. This should be a working program. No debugging will be done._ Is it correct?
# + The vets scripts may generate 2 records for a same vet name with 2 distinct specialties. Is it ok?

# %%
import random
import csv

doctorNames = ["Alvin Carpenter","Lorna Jenkins","Nisha Vang","Ashlee Owens",
        "Rojin Sparrow","Madeeha Bellamy","Ewen Stott","Franco Crouch",
        "Jensen Conroy","Clarissa Churchill","Batman","Aron Parsons",
        "Tyron Goodman","Shahzaib Petty","Julius Colley","Calista Cummings",
        "Eiliyah West","Adem Wardle","Keaton Ferry","Salman Whitley",
        "Simran Dudley","Halle Sampson","Zander Spencer","Gurveer Lutz",
        "Hasnain Mendoza","Scarlette Mohammed","Nadeem Craft","Ajay Bryan",
        "Kiera Ridley","Otto Valenzuela","Tarik Corona","Ella-Rose Choi",
        "Roland Burns","Sheena Walls","Robert Horne","Eleasha Firth",
        "Gracie Hood","Albert Cross","Domonic Keller","Kenya Hartman",
        "Luna Crosby","Isabella-Rose Hawkins","Kathryn Lindsey","Karen Diaz",
        "Gianluca Walker","Ephraim Booth","Zayan Yang","Conal Taylor",
        "Jimmie Gallegos","Ritik Moses","Lois Wong","Sylvie Yoder",
        "Romana Wagner","Kelly Hodge","Romy Cohen","Renee Park",
        "Siraj Blevins","Lexi Hendricks","Mario Easton","Aoife Wynn",
        "Devon Lowry","Mathias Russo","Fionn Cochran","Ella-Grace Hollis",
        "Karis Lane","Huseyin Sargent","Charlene Myers","Leighton Bloggs",
        "Marilyn Burks","Alessio Day","Maisha Frost","Keri Rocha","Lillie Paterson",
        "Andre Matthews","Blair Torres","Roscoe Dunne","Larissa Kinney","Camron Rees",
        "Jagdeep Sims","Sandra Wickens","Soraya Bevan","Libbi Driscoll","Shanaya Bouvet",
        "Zaynab Markham","Sinead Holland","Dougie Whelan","Rylee Hinton","Federico Ray",
        "Fatima Goodwin","Amandeep Mclean","Eleri Garza","Heath Robson","Areebah Calhoun",
        "Nour Fox","Lillie-Mae O'Neill","Margot Reyna","Ibrahim Witt","Rukhsar Roman",
        "Frida Rayner","Keir Soto","Cody Buckley"]

petNames = ["Zen","Misty","Frankie Lee Jones","Lyra","Minnie","Charlie",
            "Puck","Frankie","Pepper","Cathol","Emily","George","Jet",
            "Wilbur","Slightly","Kevin Boots Ewing","Violet","Faith","Tanner",
            "Simon","North Star","Chico","Hudson","Estrela","Lucky","Daisy",
            "Buffy","Leeloo","Zorg","Digger","Piper","Gamzee","Nepeta",
            "Cloudy","Little Bear","Bailey","Princess","Eloise","Maggie",
            "Sunbeam","Koshka","Sherman","Lellow","Cowboy","Evelyn","Wilson",
            "Pumpkin","Esco","Vinnie","Norman"]

petSpecies = ["Cat", "Dog", "Parrot", "Hamster"]
numberOfPets = random.randint(500, 1000)
numberOfDoctors = random.randint(10, 30)
f1 = open('pets.csv','w', newline='\n')
writer = csv.writer(f1)
writer.writerow(["ID","Name","Species","Age"])

for n in range(numberOfPets):
   writer.writerow([n+1001, random.choice(petNames), random.choice(petSpecies),
                    random.randint(1, 15)])

f1.close()

f1 = open('vets.csv','w', newline='\n')
writer = csv.writer(f1)
writer.writerow(["ID","Name","Specialty"])

for n in range(numberOfDoctors):
   writer.writerow([n+1001, random.choice(doctorNames), random.choice(petSpecies)])

f1.close()

# %%
class Vet:
    # simple class to model veterinarian (vet)
    def __init__(self, unique_id, name, specialty):
        self.unique_id = int(unique_id)
        self.name = name
        self.specialty = specialty    
        
        
class Pet:
    # simple class to model pet
    def __init__(self, unique_id, name, species, age, vet):        
        self.unique_id = int(unique_id)
        self.name = name
        self.species = species
        self.age = int(age)
        self.vet = vet

# %%
def get_vets_list_from_file():  
    # Returns a list of Vet instances created from CSV file.    
    file = open("vets.csv",'r')    
    lines = file.readlines()[1:]    
    vets = []
    
    for i in lines:
        line = i.split(',')        
        line[2].replace('\n','')
        
        vet = Vet(unique_id=line[0], name=line[1].strip(), specialty=line[2].strip())
        vets.append(vet)
        
    file.close()
    
    return vets   


def get_pets_list_from_file(vets):  
    # Returns a list of Vet instances created from CSV file and associates a vet
    file = open("pets.csv",'r')    
    lines = file.readlines()[1:]    
    pets = []
    
    for i in lines:
        line = i.split(',')        
        line[3].replace('\n','')        
        
        specialty = line[2]        
        vets_by_specialty = get_vets_by_specialty(vets, specialty)        
        vet_by_specialty = random.choice(vets_by_specialty)
        
        pet = Pet(unique_id=line[0], name=line[1].strip(), species=line[2].strip(), age=line[3], vet=vet_by_specialty)
        pets.append(pet)
        
    file.close()
    
    return pets  


def get_vets_by_specialty(vets, specialty):
    # filters and returns vets for a certain specialty        
    vets_by_specialty = [v for v in vets if v.specialty == specialty]        
    return vets_by_specialty


def create_vet_pet_file(pets):
    # writes the associations between vets and pets in a CSV file while loops pets list
    vet_pet = open("vet_pet.csv", "w")    
    vet_pet.write('pet.unique_id,pet.name,pet.species,pet.age,')
    vet_pet.write('vet.unique_id,vet.name,vet.specialty\n')
    
    for pet in pets:
        pet_columns = f'{pet.unique_id},{pet.name},{pet.species},{pet.age}'
        vet_columns = f'{pet.vet.unique_id},{pet.vet.name},{pet.vet.specialty}'
        vet_pet.write(f'{pet_columns},{vet_columns}\n')        
        
    vet_pet.close()

# %%
def view_all_vets(vets):
    # loops through vets list and presents every record
    print(f"\nLISTING ALL VETS:")
    for vet in vets:        
        print(f'{vet.unique_id} - {vet.name} ({vet.specialty})')     
    
    
def view_all_pets(pets):
    # loops through pets list and presents every record
    print(f"\nLISTING ALL PETS:")
    for pet in pets:        
        print(f'{pet.unique_id} - {pet.name}, {pet.age} ({pet.species})')

# %%
def get_vet_specialties(vets):
    # generates a list of specialties based on vets list
    # this approach was adopted for the sake of liability of the program, 
    # since the variable petSpecies concerns to a distinct part of the exercise
    return list(set([v.specialty.lower() for v in vets]))


def show_vet_specialties_menu(specialties):   
    # presents specialties menu
    print('\nVIEW VETS FROM SPECIFIC SPECIALTY - SPECIALTIES:')
    
    for s in specialties:
        print(f'- {s}')
        
    print(f'- <blank> - back to main menu')     
    

def get_specialty_option(vets):
    # selects and validates specialty typed by user
    specialties = get_vet_specialties(vets)
    show_vet_specialties_menu(specialties)
    
    chosen_specialty = None
    while chosen_specialty not in specialties and chosen_specialty != '':
        try:
            chosen_specialty = input('Type a specialty: ').lower().strip()
        except:
            print('\nInvalid specialty')
            pass
    
    if chosen_specialty == '':
        return;    
    
    return chosen_specialty 
    
    
def view_vets_by_specialty(vets):
    # filters and prints vets of a certain specialty
    specialty = get_specialty_option(vets)

    if specialty == None:
        return;
    
    print(f'\nVETS BY SPECIALTY ({specialty.upper()})')
    
    for v in vets:        
        if v.specialty.lower() == specialty.lower():
            print(f'{v.unique_id} - {v.name} ({v.specialty})')

# %%
def get_pet_species(pets):
    # generates a list of species based on pets list
    # this approach was adopted for the sake of liability of the program, 
    # since the variable petSpecies concerns to a distinct part of the exercise
    return list(set([p.species.lower() for p in pets]))


def show_pet_species_menu(species):   
    # presents species menu
    print('\nVIEW PETS OF A SPECIFIC SPECIES - SPECIES LIST:')
    
    for s in species:
        print(f'- {s}')
        
    print(f'- <blank> - back to main menu') 

    
def get_species_option(pets):
    # selects and validates species typed by user
    species = get_pet_species(pets)
    show_pet_species_menu(species)
    
    chosen_species = None
    while chosen_species not in species and chosen_species != '':
        try:
            chosen_species = input('Type a species: ').lower().strip()
        except:
            print('\nInvalid species')
            pass
    
    if chosen_species == '':
        return;    
    
    return chosen_species             
            
            
def view_pets_by_species(pets):
    # filters and prints pets of a certain species
    species = get_species_option(pets)
    
    if species == None:
        return;
    
    print(f'\nPETS BY SPECIES ({species.upper()})')
    
    for p in pets:        
        if p.species.lower() == species.lower():
            print(f'{p.unique_id} - {p.name}, {p.age} ({p.species})')

# %%
def view_pets_by_vet(vets, pets):
    # find a particular vet given their ID and view all pets associated to them
    print('\nFIND VET AND VIEW THEIR PETS')
    vet_id = int(input('Type Vet ID (or <blank> to go back to main menu):'))    
    vet = next((v for v in vets if v.unique_id == vet_id), None)
    
    if vet == None:
        print(f'vet id #{vet_id} cannot be found')
        return
          
    print(f'\nVET: {vet.name} ({vet.specialty})')     
    pets_by_vet = [p for p in pets if p.vet.unique_id == vet.unique_id]
    print(f'ALL PETS ASSOCIATES TO {vet.name}:')
    for p in pets_by_vet:
        print(f'{p.unique_id} - {p.name}, {p.age} ({p.species}); Vet ID: {p.vet.unique_id}') 
        
        
def find_pet_by_id(pets):
    # find a particular pet given its id and view its pet
    print('\nFIND PET AND VIEW ITS VET')
    pet_id = int(input('Type Pet ID (or <blank> to go back to main menu):'))    
    pet = next((p for p in pets if p.unique_id == pet_id), None)
    
    if pet == None:
        print(f'pet id #{pet_id} cannot be found')
        return
    
    print(f'\nPET: {pet.name}, {pet.age} ({pet.species})')
    print(f"{pet.name}'s vet is {pet.vet.name} (vet id {pet.vet.unique_id})")

# %%
def show_main_menu():
    # presents the system features
    print('\nVET CLINIC SYSTEM - MAIN MENU')
    print('1 - View All Vets')
    print('2 - View All Pets')   
    print('3 - View Vets From Specific Specialty')   
    print('4 - View Pets Of Specific Species')   
    print('5 - Find Vet And View Their Pets')   
    print('6 - Find Pet And View Its Vet')   
    print("0 - Exit Program")
    
    
def get_main_menu_option():
    # requires a menu option from user and validates it
    valid_options = [0,1,2,3,4,5,6]
    option = None
    
    while option not in valid_options:
        try:
            option = int(input('Choose your option: '))
        except:
            pass
        
    return option    


vets = get_vets_list_from_file()
pets = get_pets_list_from_file(vets)           
create_vet_pet_file(pets)     

def vet_clinic():    
    # main program        
    option = None
    
    while option != 0:
        show_main_menu()    
        option = get_main_menu_option()
        
        if option == 0:
            print('\nBye-bye!')
        if option == 1:
            view_all_vets(vets)         
        if option == 2:
            view_all_pets(pets)    
        if option == 3:
            view_vets_by_specialty(vets)
        if option == 4:
            view_pets_by_species(pets)  
        if option == 5:
            view_pets_by_vet(vets, pets)
        if option == 6:
            find_pet_by_id(pets)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-12-d0a6564773cc> in <module>
#      27 vets = get_vets_list_from_file()
#      28 pets = get_pets_list_from_file(vets)
# ---> 29 create_vet_pet_file(pets)
#      30
#      31 def vet_clinic():
#
# <ipython-input-3-043765ab3912> in create_vet_pet_file(pets)
#      47 def create_vet_pet_file(pets):
#      48     # writes the associations between vets and pets in a CSV file while loops pets list
# ---> 49     vet_pet = open("vet_pet.csv", "w")
#      50     vet_pet.write('pet.unique_id,pet.name,pet.species,pet.age,')
#      51     vet_pet.write('vet.unique_id,vet.name,vet.specialty\n')
#
# PermissionError: [Errno 13] Permission denied: 'vet_pet.csv'

# %%
vet_clinic()
# Out:
# VET CLINIC SYSTEM - MAIN MENU
# 1 - View All Vets
# 2 - View All Pets
# 3 - View Vets From Specific Specialty
# 4 - View Pets Of Specific Species
# 5 - Find Vet And View Their Pets
# 6 - Find Pet And View Its Vet
# 0 - Exit Program
# Choose your option: 2
#
# LISTING ALL PETS:
# 1001 - Frankie Lee Jones, 13 (Parrot)
# 1002 - Esco, 9 (Hamster)
# 1003 - North Star, 1 (Cat)
# 1004 - Frankie, 8 (Dog)
# 1005 - Evelyn, 8 (Hamster)
# 1006 - Lyra, 15 (Dog)
# 1007 - Tanner, 7 (Hamster)
# 1008 - Koshka, 6 (Hamster)
# 1009 - Violet, 9 (Parrot)
# 1010 - Lyra, 5 (Dog)
# 1011 - Estrela, 8 (Cat)
# 1012 - North Star, 14 (Parrot)
# 1013 - Nepeta, 1 (Cat)
# 1014 - Pumpkin, 6 (Parrot)
# 1015 - Pumpkin, 4 (Hamster)
# 1016 - Sherman, 6 (Parrot)
# 1017 - Misty, 12 (Parrot)
# 1018 - Jet, 8 (Parrot)
# 1019 - George, 11 (Cat)
# 1020 - Puck, 10 (Parrot)
# 1021 - Lucky, 2 (Parrot)
# 1022 - Pumpkin, 10 (Parrot)
# 1023 - Evelyn, 9 (Cat)
# 1024 - Jet, 4 (Dog)
# 1025 - Esco, 11 (Parrot)
# 1026 - Kevin Boots Ewing, 1 (Hamster)
# 1027 - Slightly, 3 (Cat)
# 1028 - Wilbur, 12 (Parrot)
# 1029 - Gamzee, 8 (Hamster)
# 1030 - Cloudy, 2 (Dog)
# 1031 - Frankie Lee Jones, 4 (Hamster)
# 1032 - Cloudy, 3 (Dog)
# 1033 - Pumpkin, 8 (Dog)
# 1034 - Sunbeam, 1 (Cat)
# 1035 - Koshka, 9 (Dog)
# 1036 - Maggie, 5 (Cat)
# 1037 - Piper, 1 (Parrot)
# 1038 - Tanner, 1 (Parrot)
# 1039 - Esco, 7 (Dog)
# 1040 - Kevin Boots Ewing, 6 (Hamster)
# 1041 - Faith, 11 (Parrot)
# 1042 - Nepeta, 4 (Parrot)
# 1043 - Pumpkin, 14 (Parrot)
# 1044 - Little Bear, 13 (Hamster)
# 1045 - Koshka, 15 (Hamster)
# 1046 - Wilbur, 15 (Cat)
# 1047 - George, 2 (Hamster)
# 1048 - Minnie, 9 (Cat)
# 1049 - Chico, 15 (Cat)
# 1050 - Lellow, 14 (Cat)
# 1051 - Pumpkin, 9 (Dog)
# 1052 - Emily, 14 (Cat)
# 1053 - Piper, 8 (Hamster)
# 1054 - Princess, 15 (Parrot)
# 1055 - Chico, 4 (Hamster)
# 1056 - Misty, 9 (Hamster)
# 1057 - Puck, 7 (Parrot)
# 1058 - Gamzee, 4 (Cat)
# 1059 - Zen, 5 (Parrot)
# 1060 - Zorg, 15 (Cat)
# 1061 - Frankie Lee Jones, 7 (Dog)
# 1062 - Lellow, 8 (Cat)
# 1063 - Wilson, 9 (Dog)
# 1064 - Zen, 6 (Cat)
# 1065 - Lyra, 1 (Cat)
# 1066 - Wilson, 15 (Cat)
# 1067 - Cathol, 3 (Cat)
# 1068 - Cathol, 8 (Hamster)
# 1069 - Lucky, 2 (Hamster)
# 1070 - Nepeta, 3 (Dog)
# 1071 - Sherman, 4 (Hamster)
# 1072 - Nepeta, 15 (Cat)
# 1073 - Zen, 11 (Dog)
# 1074 - Little Bear, 10 (Hamster)
# 1075 - Cloudy, 7 (Dog)
# 1076 - Maggie, 13 (Cat)
# 1077 - Misty, 14 (Hamster)
# 1078 - Misty, 2 (Dog)
# 1079 - Estrela, 9 (Dog)
# 1080 - Buffy, 9 (Dog)
# 1081 - Cloudy, 15 (Dog)
# 1082 - Pumpkin, 6 (Cat)
# 1083 - Simon, 1 (Dog)
# 1084 - Kevin Boots Ewing, 4 (Hamster)
# 1085 - Simon, 8 (Dog)
# 1086 - Faith, 3 (Dog)
# 1087 - Lellow, 2 (Dog)
# 1088 - Buffy, 3 (Cat)
# 1089 - Piper, 6 (Dog)
# 1090 - Gamzee, 5 (Cat)
# 1091 - Lyra, 14 (Parrot)
# 1092 - George, 3 (Parrot)
# 1093 - Eloise, 11 (Dog)
# 1094 - Slightly, 4 (Hamster)
# 1095 - Leeloo, 6 (Parrot)
# 1096 - Princess, 3 (Hamster)
# 1097 - Emily, 9 (Hamster)
# 1098 - Gamzee, 9 (Dog)
# 1099 - Misty, 15 (Parrot)
# 1100 - Tanner, 10 (Cat)
# 1101 - North Star, 12 (Parrot)
# 1102 - Misty, 3 (Parrot)
# 1103 - Little Bear, 11 (Dog)
# 1104 - Emily, 12 (Hamster)
# 1105 - Hudson, 11 (Hamster)
# 1106 - Wilbur, 6 (Parrot)
# 1107 - Piper, 14 (Hamster)
# 1108 - Tanner, 10 (Dog)
# 1109 - Puck, 6 (Cat)
# 1110 - Gamzee, 5 (Dog)
# 1111 - George, 6 (Hamster)
# 1112 - Estrela, 4 (Cat)
# 1113 - North Star, 1 (Dog)
# 1114 - Lyra, 10 (Parrot)
# 1115 - Zen, 10 (Dog)
# 1116 - Slightly, 13 (Dog)
# 1117 - Puck, 6 (Hamster)
# 1118 - Lucky, 2 (Hamster)
# 1119 - Tanner, 9 (Hamster)
# 1120 - Zen, 5 (Cat)
# 1121 - Zorg, 15 (Hamster)
# 1122 - Charlie, 6 (Cat)
# 1123 - Frankie, 2 (Dog)
# 1124 - Vinnie, 15 (Hamster)
# 1125 - Lellow, 15 (Dog)
# 1126 - Sunbeam, 3 (Parrot)
# 1127 - Simon, 8 (Dog)
# 1128 - Misty, 2 (Parrot)
# 1129 - Lellow, 9 (Cat)
# 1130 - Minnie, 9 (Dog)
# 1131 - North Star, 4 (Hamster)
# 1132 - Estrela, 3 (Hamster)
# 1133 - Little Bear, 5 (Cat)
# 1134 - Evelyn, 5 (Cat)
# 1135 - Misty, 14 (Hamster)
# 1136 - Kevin Boots Ewing, 1 (Hamster)
# 1137 - Koshka, 13 (Parrot)
# 1138 - Lucky, 13 (Dog)
# 1139 - Nepeta, 15 (Parrot)
# 1140 - Estrela, 3 (Dog)
# 1141 - Violet, 2 (Dog)
# 1142 - Esco, 5 (Parrot)
# 1143 - Hudson, 8 (Hamster)
# 1144 - Kevin Boots Ewing, 1 (Hamster)
# 1145 - Wilbur, 14 (Parrot)
# 1146 - Estrela, 15 (Dog)
# 1147 - Wilson, 10 (Dog)
# 1148 - Daisy, 3 (Parrot)
# 1149 - Evelyn, 13 (Dog)
# 1150 - Emily, 10 (Cat)
# 1151 - Leeloo, 6 (Dog)
# 1152 - Sunbeam, 15 (Cat)
# 1153 - Violet, 11 (Cat)
# 1154 - Minnie, 12 (Dog)
# 1155 - Slightly, 13 (Cat)
# 1156 - Simon, 13 (Dog)
# 1157 - Norman, 5 (Parrot)
# 1158 - Gamzee, 14 (Dog)
# 1159 - Eloise, 9 (Cat)
# 1160 - Little Bear, 12 (Dog)
# 1161 - Buffy, 4 (Cat)
# 1162 - George, 10 (Cat)
# 1163 - Pumpkin, 1 (Parrot)
# 1164 - Koshka, 5 (Cat)
# 1165 - Digger, 14 (Cat)
# 1166 - Gamzee, 7 (Hamster)
# 1167 - Cloudy, 12 (Cat)
# 1168 - Eloise, 13 (Cat)
# 1169 - Chico, 10 (Cat)
# 1170 - George, 14 (Cat)
# 1171 - Hudson, 12 (Parrot)
# 1172 - Misty, 5 (Cat)
# 1173 - Cathol, 13 (Cat)
# 1174 - Simon, 14 (Parrot)
# 1175 - Zorg, 5 (Hamster)
# 1176 - Pumpkin, 11 (Cat)
# 1177 - Puck, 14 (Hamster)
# 1178 - Estrela, 1 (Hamster)
# 1179 - Sherman, 5 (Cat)
# 1180 - Puck, 14 (Cat)
# 1181 - Tanner, 5 (Cat)
# 1182 - Simon, 6 (Dog)
# 1183 - Zorg, 10 (Cat)
# 1184 - Nepeta, 1 (Parrot)
# 1185 - Faith, 14 (Parrot)
# 1186 - Wilson, 14 (Hamster)
# 1187 - Violet, 13 (Cat)
# 1188 - Pepper, 6 (Dog)
# 1189 - Puck, 5 (Cat)
# 1190 - Faith, 11 (Parrot)
# 1191 - Wilbur, 11 (Parrot)
# 1192 - Misty, 4 (Parrot)
# 1193 - Princess, 7 (Dog)
# 1194 - Bailey, 15 (Hamster)
# 1195 - Little Bear, 6 (Dog)
# 1196 - Lucky, 9 (Hamster)
# 1197 - Gamzee, 8 (Cat)
# 1198 - Pumpkin, 1 (Parrot)
# 1199 - Lyra, 1 (Cat)
# 1200 - Misty, 3 (Cat)
# 1201 - Maggie, 14 (Hamster)
# 1202 - Hudson, 5 (Dog)
# 1203 - Lellow, 7 (Parrot)
# 1204 - Cloudy, 6 (Dog)
# 1205 - Evelyn, 3 (Cat)
# 1206 - Tanner, 1 (Hamster)
# 1207 - Slightly, 8 (Hamster)
# 1208 - Leeloo, 8 (Parrot)
# 1209 - Lyra, 7 (Cat)
# 1210 - Simon, 12 (Hamster)
# 1211 - Pumpkin, 13 (Parrot)
# 1212 - Cloudy, 14 (Hamster)
# 1213 - Tanner, 4 (Dog)
# 1214 - Violet, 4 (Cat)
# 1215 - Cathol, 5 (Parrot)
# 1216 - Charlie, 4 (Parrot)
# 1217 - Tanner, 1 (Parrot)
# 1218 - Simon, 2 (Cat)
# 1219 - Pepper, 4 (Dog)
# 1220 - Zen, 12 (Dog)
# 1221 - Misty, 9 (Dog)
# 1222 - Zorg, 10 (Hamster)
# 1223 - Princess, 11 (Cat)
# 1224 - Slightly, 11 (Parrot)
# 1225 - Tanner, 12 (Parrot)
# 1226 - Cowboy, 6 (Hamster)
# 1227 - Sherman, 6 (Hamster)
# 1228 - Kevin Boots Ewing, 9 (Parrot)
# 1229 - Puck, 1 (Dog)
# 1230 - Slightly, 7 (Parrot)
# 1231 - Sherman, 5 (Cat)
# 1232 - Maggie, 5 (Parrot)
# 1233 - Simon, 12 (Dog)
# 1234 - Cathol, 13 (Dog)
# 1235 - Zen, 7 (Cat)
# 1236 - Zorg, 2 (Dog)
# 1237 - Faith, 11 (Hamster)
# 1238 - Chico, 15 (Dog)
# 1239 - Eloise, 8 (Dog)
# 1240 - Cloudy, 13 (Dog)
# 1241 - Koshka, 9 (Cat)
# 1242 - Hudson, 5 (Dog)
# 1243 - Misty, 5 (Parrot)
# 1244 - Zorg, 2 (Parrot)
# 1245 - Slightly, 2 (Hamster)
# 1246 - Estrela, 13 (Dog)
# 1247 - Sunbeam, 1 (Parrot)
# 1248 - Sherman, 10 (Cat)
# 1249 - Pumpkin, 2 (Dog)
# 1250 - Zen, 5 (Parrot)
# 1251 - Tanner, 4 (Parrot)
# 1252 - Faith, 8 (Parrot)
# 1253 - Hudson, 1 (Hamster)
# 1254 - Tanner, 5 (Parrot)
# 1255 - Wilson, 14 (Cat)
# 1256 - Sherman, 8 (Hamster)
# 1257 - Koshka, 8 (Dog)
# 1258 - Faith, 15 (Hamster)
# 1259 - Nepeta, 7 (Hamster)
# 1260 - Lucky, 11 (Cat)
# 1261 - Simon, 4 (Parrot)
# 1262 - Violet, 14 (Parrot)
# 1263 - Vinnie, 9 (Cat)
# 1264 - Jet, 5 (Dog)
# 1265 - Minnie, 7 (Cat)
# 1266 - Vinnie, 3 (Parrot)
# 1267 - Cowboy, 11 (Hamster)
# 1268 - Norman, 7 (Cat)
# 1269 - Little Bear, 7 (Cat)
# 1270 - Faith, 11 (Dog)
# 1271 - Zen, 1 (Parrot)
# 1272 - Evelyn, 8 (Hamster)
# 1273 - Piper, 8 (Cat)
# 1274 - Pepper, 1 (Cat)
# 1275 - Jet, 13 (Hamster)
# 1276 - Hudson, 9 (Cat)
# 1277 - Gamzee, 13 (Dog)
# 1278 - Evelyn, 9 (Parrot)
# 1279 - Lucky, 4 (Hamster)
# 1280 - Daisy, 10 (Cat)
# 1281 - Pepper, 4 (Hamster)
# 1282 - North Star, 1 (Dog)
# 1283 - Evelyn, 14 (Dog)
# 1284 - Cathol, 1 (Dog)
# 1285 - Eloise, 3 (Hamster)
# 1286 - Maggie, 8 (Cat)
# 1287 - Pepper, 15 (Parrot)
# 1288 - Cloudy, 2 (Hamster)
# 1289 - Misty, 14 (Hamster)
# 1290 - Violet, 8 (Hamster)
# 1291 - Esco, 7 (Dog)
# 1292 - Maggie, 3 (Parrot)
# 1293 - Pepper, 4 (Parrot)
# 1294 - Princess, 3 (Parrot)
# 1295 - Nepeta, 5 (Parrot)
# 1296 - Chico, 8 (Parrot)
# 1297 - Frankie Lee Jones, 3 (Dog)
# 1298 - Simon, 9 (Hamster)
# 1299 - Leeloo, 1 (Cat)
# 1300 - Lyra, 4 (Parrot)
# 1301 - North Star, 15 (Cat)
# 1302 - Charlie, 11 (Parrot)
# 1303 - Lucky, 1 (Dog)
# 1304 - Pepper, 11 (Dog)
# 1305 - Wilson, 8 (Parrot)
# 1306 - Koshka, 6 (Dog)
# 1307 - Sherman, 6 (Hamster)
# 1308 - Chico, 8 (Parrot)
# 1309 - George, 5 (Parrot)
# 1310 - Emily, 4 (Hamster)
# 1311 - Nepeta, 8 (Dog)
# 1312 - Wilbur, 6 (Dog)
# 1313 - Bailey, 15 (Parrot)
# 1314 - North Star, 2 (Parrot)
# 1315 - Jet, 11 (Cat)
# 1316 - Emily, 4 (Hamster)
# 1317 - Frankie, 1 (Cat)
# 1318 - Wilson, 7 (Cat)
# 1319 - Eloise, 8 (Parrot)
# 1320 - Violet, 12 (Cat)
# 1321 - Eloise, 8 (Dog)
# 1322 - Nepeta, 3 (Hamster)
# 1323 - Norman, 12 (Cat)
# 1324 - Estrela, 10 (Cat)
# 1325 - Gamzee, 2 (Dog)
# 1326 - Leeloo, 13 (Dog)
# 1327 - Wilbur, 8 (Cat)
# 1328 - Cathol, 13 (Dog)
# 1329 - Faith, 8 (Cat)
# 1330 - Zen, 10 (Dog)
# 1331 - Frankie, 4 (Dog)
# 1332 - Simon, 10 (Dog)
# 1333 - Tanner, 15 (Parrot)
# 1334 - Lyra, 4 (Hamster)
# 1335 - Zen, 1 (Dog)
# 1336 - Evelyn, 8 (Parrot)
# 1337 - Frankie Lee Jones, 12 (Cat)
# 1338 - Vinnie, 13 (Parrot)
# 1339 - Leeloo, 7 (Hamster)
# 1340 - Hudson, 10 (Dog)
# 1341 - Evelyn, 8 (Cat)
# 1342 - Leeloo, 9 (Hamster)
# 1343 - Buffy, 13 (Hamster)
# 1344 - Leeloo, 12 (Hamster)
# 1345 - Eloise, 1 (Parrot)
# 1346 - Cloudy, 10 (Hamster)
# 1347 - Leeloo, 9 (Cat)
# 1348 - Lyra, 8 (Hamster)
# 1349 - Tanner, 14 (Parrot)
# 1350 - Digger, 11 (Hamster)
# 1351 - Koshka, 9 (Parrot)
# 1352 - Frankie Lee Jones, 9 (Cat)
# 1353 - Misty, 6 (Hamster)
# 1354 - Puck, 1 (Parrot)
# 1355 - Simon, 4 (Parrot)
# 1356 - Sunbeam, 12 (Dog)
# 1357 - Cathol, 13 (Dog)
# 1358 - Zen, 9 (Parrot)
# 1359 - Nepeta, 3 (Hamster)
# 1360 - Lyra, 11 (Parrot)
# 1361 - Sherman, 15 (Dog)
# 1362 - Piper, 4 (Hamster)
# 1363 - Slightly, 4 (Parrot)
# 1364 - Daisy, 3 (Cat)
# 1365 - Cloudy, 13 (Parrot)
# 1366 - Daisy, 2 (Dog)
# 1367 - Gamzee, 14 (Dog)
# 1368 - Norman, 14 (Cat)
# 1369 - Eloise, 13 (Hamster)
# 1370 - Chico, 9 (Cat)
# 1371 - Leeloo, 10 (Hamster)
# 1372 - Chico, 5 (Cat)
# 1373 - Maggie, 9 (Cat)
# 1374 - Misty, 8 (Hamster)
# 1375 - Puck, 1 (Cat)
# 1376 - Jet, 7 (Hamster)
# 1377 - Violet, 14 (Dog)
# 1378 - Pumpkin, 3 (Cat)
# 1379 - Koshka, 8 (Cat)
# 1380 - Digger, 7 (Cat)
# 1381 - Nepeta, 12 (Parrot)
# 1382 - Cowboy, 13 (Dog)
# 1383 - Violet, 1 (Hamster)
# 1384 - Evelyn, 13 (Parrot)
# 1385 - Little Bear, 11 (Parrot)
# 1386 - Estrela, 2 (Dog)
# 1387 - Sherman, 9 (Hamster)
# 1388 - Chico, 4 (Cat)
# 1389 - Simon, 14 (Hamster)
# 1390 - Lellow, 11 (Hamster)
# 1391 - Tanner, 5 (Parrot)
# 1392 - Eloise, 7 (Hamster)
# 1393 - Bailey, 13 (Hamster)
# 1394 - Eloise, 11 (Parrot)
# 1395 - Gamzee, 13 (Cat)
# 1396 - Lyra, 2 (Parrot)
# 1397 - Lucky, 4 (Hamster)
# 1398 - Kevin Boots Ewing, 8 (Cat)
# 1399 - Faith, 11 (Cat)
# 1400 - Evelyn, 3 (Dog)
# 1401 - Charlie, 8 (Hamster)
# 1402 - North Star, 10 (Hamster)
# 1403 - Frankie, 11 (Parrot)
# 1404 - Misty, 4 (Cat)
# 1405 - Nepeta, 13 (Hamster)
# 1406 - Violet, 2 (Parrot)
# 1407 - Little Bear, 7 (Parrot)
# 1408 - Vinnie, 4 (Hamster)
# 1409 - Pepper, 2 (Hamster)
# 1410 - Piper, 11 (Dog)
# 1411 - Frankie, 12 (Hamster)
# 1412 - Wilbur, 8 (Parrot)
# 1413 - Nepeta, 13 (Cat)
# 1414 - Frankie, 6 (Hamster)
# 1415 - Maggie, 1 (Dog)
# 1416 - Zen, 7 (Parrot)
# 1417 - Lucky, 5 (Dog)
# 1418 - Puck, 7 (Parrot)
# 1419 - Koshka, 5 (Dog)
# 1420 - Eloise, 3 (Dog)
# 1421 - Bailey, 15 (Hamster)
# 1422 - Esco, 11 (Hamster)
# 1423 - Cowboy, 4 (Hamster)
# 1424 - North Star, 5 (Dog)
# 1425 - Frankie, 7 (Hamster)
# 1426 - Piper, 4 (Hamster)
# 1427 - Charlie, 3 (Cat)
# 1428 - Nepeta, 5 (Cat)
# 1429 - Vinnie, 6 (Dog)
# 1430 - Wilbur, 8 (Hamster)
# 1431 - Wilbur, 10 (Parrot)
# 1432 - Charlie, 15 (Cat)
# 1433 - North Star, 9 (Dog)
# 1434 - Little Bear, 7 (Dog)
# 1435 - Wilson, 5 (Parrot)
# 1436 - Cloudy, 6 (Cat)
# 1437 - Frankie, 10 (Dog)
# 1438 - Lucky, 14 (Cat)
# 1439 - Kevin Boots Ewing, 4 (Hamster)
# 1440 - Lellow, 7 (Dog)
# 1441 - Wilbur, 7 (Hamster)
# 1442 - Wilbur, 11 (Hamster)
# 1443 - Jet, 6 (Hamster)
# 1444 - Sherman, 3 (Parrot)
# 1445 - Pumpkin, 6 (Dog)
# 1446 - Misty, 12 (Cat)
# 1447 - Minnie, 12 (Cat)
# 1448 - Frankie, 2 (Hamster)
# 1449 - Cloudy, 13 (Hamster)
# 1450 - Pumpkin, 13 (Hamster)
# 1451 - Koshka, 2 (Dog)
# 1452 - Kevin Boots Ewing, 13 (Dog)
# 1453 - Misty, 10 (Hamster)
# 1454 - Vinnie, 15 (Parrot)
# 1455 - Charlie, 1 (Cat)
# 1456 - Wilbur, 2 (Hamster)
# 1457 - Piper, 15 (Dog)
# 1458 - Zorg, 15 (Dog)
# 1459 - Frankie, 14 (Dog)
# 1460 - Wilson, 11 (Parrot)
# 1461 - Estrela, 12 (Hamster)
# 1462 - Bailey, 9 (Cat)
# 1463 - Pumpkin, 9 (Dog)
# 1464 - Pepper, 7 (Dog)
# 1465 - Frankie Lee Jones, 1 (Hamster)
# 1466 - Buffy, 15 (Cat)
# 1467 - Charlie, 12 (Cat)
# 1468 - George, 5 (Cat)
# 1469 - Little Bear, 11 (Dog)
# 1470 - George, 11 (Cat)
# 1471 - Eloise, 6 (Parrot)
# 1472 - Minnie, 7 (Parrot)
# 1473 - Sunbeam, 4 (Parrot)
# 1474 - Misty, 15 (Hamster)
# 1475 - Nepeta, 3 (Hamster)
# 1476 - Kevin Boots Ewing, 3 (Dog)
# 1477 - Faith, 6 (Cat)
# 1478 - Wilbur, 12 (Parrot)
# 1479 - Digger, 15 (Dog)
# 1480 - Hudson, 6 (Hamster)
# 1481 - Cowboy, 9 (Dog)
# 1482 - Misty, 14 (Hamster)
# 1483 - Faith, 13 (Parrot)
# 1484 - Frankie Lee Jones, 3 (Cat)
# 1485 - Tanner, 14 (Cat)
# 1486 - Maggie, 12 (Cat)
# 1487 - Simon, 3 (Hamster)
# 1488 - Daisy, 5 (Cat)
# 1489 - Buffy, 2 (Hamster)
# 1490 - Sunbeam, 11 (Cat)
# 1491 - Cathol, 15 (Cat)
# 1492 - Frankie Lee Jones, 9 (Hamster)
# 1493 - Estrela, 15 (Hamster)
# 1494 - Kevin Boots Ewing, 3 (Cat)
# 1495 - Bailey, 14 (Parrot)
# 1496 - Cloudy, 15 (Parrot)
# 1497 - Chico, 9 (Cat)
# 1498 - George, 13 (Dog)
# 1499 - Gamzee, 12 (Dog)
# 1500 - Kevin Boots Ewing, 15 (Parrot)
# 1501 - Pepper, 4 (Cat)
# 1502 - Emily, 6 (Cat)
# 1503 - Sherman, 8 (Cat)
# 1504 - Charlie, 5 (Hamster)
# 1505 - Frankie, 14 (Dog)
#
# VET CLINIC SYSTEM - MAIN MENU
# 1 - View All Vets
# 2 - View All Pets
# 3 - View Vets From Specific Specialty
# 4 - View Pets Of Specific Species
# 5 - Find Vet And View Their Pets
# 6 - Find Pet And View Its Vet
# 0 - Exit Program
# Choose your option: 3
#
# VIEW VETS FROM SPECIFIC SPECIALTY - SPECIALTIES:
# - dog
# - hamster
# - cat
# - parrot
# - <blank> - back to main menu
# Type a specialty: dof
# Type a specialty:    DOG
#
# VETS BY SPECIALTY (DOG)
# 1001 - Eleri Garza (Dog)
# 1005 - Salman Whitley (Dog)
# 1007 - Ajay Bryan (Dog)
# 1008 - Isabella-Rose Hawkins (Dog)
# 1024 - Margot Reyna (Dog)
# 1026 - Sandra Wickens (Dog)
# 1029 - Batman (Dog)
# 1030 - Nour Fox (Dog)
#
# VET CLINIC SYSTEM - MAIN MENU
# 1 - View All Vets
# 2 - View All Pets
# 3 - View Vets From Specific Specialty
# 4 - View Pets Of Specific Species
# 5 - Find Vet And View Their Pets
# 6 - Find Pet And View Its Vet
# 0 - Exit Program
# Choose your option: 6
#
# FIND PET AND VIEW ITS VET
# Type Pet ID (or <blank> to go back to main menu):1001
#
# PET: Frankie Lee Jones, 13 (Parrot)
# Frankie Lee Jones's vet is Devon Lowry (vet id 1002)
#
# VET CLINIC SYSTEM - MAIN MENU
# 1 - View All Vets
# 2 - View All Pets
# 3 - View Vets From Specific Specialty
# 4 - View Pets Of Specific Species
# 5 - Find Vet And View Their Pets
# 6 - Find Pet And View Its Vet
# 0 - Exit Program
# Choose your option: 5
#
# FIND VET AND VIEW THEIR PETS
# Type Vet ID (or <blank> to go back to main menu):1002
#
# VET: Devon Lowry (Parrot)
# ALL PETS ASSOCIATES TO Devon Lowry:
# 1001 - Frankie Lee Jones, 13 (Parrot); Vet ID: 1002
# 1022 - Pumpkin, 10 (Parrot); Vet ID: 1002
# 1041 - Faith, 11 (Parrot); Vet ID: 1002
# 1042 - Nepeta, 4 (Parrot); Vet ID: 1002
# 1092 - George, 3 (Parrot); Vet ID: 1002
# 1095 - Leeloo, 6 (Parrot); Vet ID: 1002
# 1142 - Esco, 5 (Parrot); Vet ID: 1002
# 1145 - Wilbur, 14 (Parrot); Vet ID: 1002
# 1208 - Leeloo, 8 (Parrot); Vet ID: 1002
# 1216 - Charlie, 4 (Parrot); Vet ID: 1002
# 1232 - Maggie, 5 (Parrot); Vet ID: 1002
# 1262 - Violet, 14 (Parrot); Vet ID: 1002
# 1305 - Wilson, 8 (Parrot); Vet ID: 1002
# 1308 - Chico, 8 (Parrot); Vet ID: 1002
# 1319 - Eloise, 8 (Parrot); Vet ID: 1002
# 1349 - Tanner, 14 (Parrot); Vet ID: 1002
# 1354 - Puck, 1 (Parrot); Vet ID: 1002
# 1385 - Little Bear, 11 (Parrot); Vet ID: 1002
# 1391 - Tanner, 5 (Parrot); Vet ID: 1002
# 1406 - Violet, 2 (Parrot); Vet ID: 1002
# 1407 - Little Bear, 7 (Parrot); Vet ID: 1002
#
# VET CLINIC SYSTEM - MAIN MENU
# 1 - View All Vets
# 2 - View All Pets
# 3 - View Vets From Specific Specialty
# 4 - View Pets Of Specific Species
# 5 - Find Vet And View Their Pets
# 6 - Find Pet And View Its Vet
# 0 - Exit Program
# Choose your option: 0
#
# Bye-bye!
